# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import math

dfS2 = pd.read_csv('https://media.githubusercontent.com/media/joaoascensao/S-L-REL606-BarSeq/master/E_F/data/bc_counts/FS2_counts.csv')
r_totS2 = pd.read_csv('https://media.githubusercontent.com/media/joaoascensao/S-L-REL606-BarSeq/master/E_F/data/bc_counts/FS2_Rtot.csv')
outliersS2 = pd.read_csv('https://media.githubusercontent.com/media/joaoascensao/S-L-REL606-BarSeq/master/E_F/data/outliers/FS2_outliers.csv')

RD_threshold=6 # defined in SI (sec S3.5) of Ascensao et al 2022
cond1=outliersS2['RD'] > RD_threshold
cond2=outliersS2['RD'] == -1
outliersS2=outliersS2[cond1 | cond2]
dfS2 = dfS2[~dfS2.barcode.isin(outliersS2.barcode)]

gene_index = []
for gene in dfS2["gene_ID"]:
    gene_index.append(gene)
#df.index = gene_index
dfS2.dropna(subset = ["gene_ID"], inplace = True)
dfS2 = dfS2.reset_index() 

all_genes = [] #list of all gene_IDs
for gene in gene_index:
    if gene != "NaN" and gene != "nan" and gene not in all_genes:
        all_genes.append(gene)
all_genes.pop(0)
print(len(all_genes))
print(len(dfS2))

r_totS2 = r_totS2.iloc[: , 1:]
dfS2.head()
# Out:
# 3462
# 201960
#    index               barcode  0_1  0_2    1   2   3   4 strand        pos  \
# 0     34  GACTGGACTCTGACTACAAA   13   35   34   0  12   0      -   263938.0
# 1     35  CCTAAGCGCTTACCCCAACC   42  116   10  53  10  23      +  2881032.0
# 2     36  TCGGACCCAGCTTGGAATAA   48  107  104  69  52  91      +  4065973.0
# 3     37  TACCTCGGTCAAGGCGTCTA    8   35   32  32  20   0      -  2824332.0
# 4     40  TATGATTCACCTCTTTATAC   21   32   31  25  16  13      -  1790824.0
#
#      gene_ID type gene_symbol                            description
# 0  ECB_00238  cds        phoE  outer membrane phosphoporin protein E
# 1  ECB_02693  cds        yqeG                  predicted transporter
# 2  ECB_03781  cds        yiiG                   hypothetical protein
# 3  ECB_02648  cds         NaN          L-fuculose phosphate aldolase
# 4  ECB_01700  cds        cedA                cell division modulator

# %%
all_dfs = {} #dictionary of gene_ID to corresponding dataframe
for gene in all_genes:            
    all_dfs[gene] = dfS2[dfS2.gene_ID == gene]

# %%
#discard of counts under an average of 30
def discard(df):
    to_discard = []
    for i in range(len(df)):
        sum = 0
        for day in ["0_1","0_2","1","2","3","4"]:
            sum += df.loc[i,day] 
        if sum/6 < 30: #average count across days is < 30 --> discard
            to_discard.append(i)
    return to_discard

dfS2_dropped = dfS2.copy()

dfS2_dropped.drop(labels=discard(dfS2), axis=0, inplace=True)
dfS2_dropped =  dfS2_dropped.groupby('gene_ID').filter(lambda x : len(x)>3)
print(len(discard(dfS2)))
dfS2_dropped = dfS2_dropped.reset_index() 
print(len(dfS2_dropped))
dfS2_dropped.head(50)
# Out:
# 145793
# 54483
#     level_0  index               barcode  0_1  0_2    1    2    3   4 strand  \
# 0         1     35  CCTAAGCGCTTACCCCAACC   42  116   10   53   10  23      +
# 1         2     36  TCGGACCCAGCTTGGAATAA   48  107  104   69   52  91      +
# 40      114    209  GTCGCGATACTTACCCGCAT   53   89   35   13   42  46      +
# 41      119    214  CCCTACCAGGCCACACCCCT  138  130  134   54  132  91      +
# 42      120    215  TCTGCCCTAGTGCGACCTTA   29   45   57   73   52  57      -
# 43      121    216  CGCTAGGCTGTGAGTCCGTA   42   37   49   74  117  12      +
# 44      122    218  CCCTGTACGGCTTGTTCCAC   66   37   63   52   97  53      -
# 45      127    225  GCCCATTCCCCATCACCTCG   64   66   65   88   70  94      -
# 46      128    226  CTCCCCCCCGGTCCCGCCCT   32   80   30   50    7  15      -
# 47      156    267  AAAGCCCCGCTCCCTCGCCG   43   51   33   71   28  29      +
# 48      160    271  GAACGCCCGGATCACCCACC   27   37   11   56   26  28      +
# 49      162    274  ACGCACTCGCACCAGAAGGC   58   49   52   67   59  23      +
#
#           pos    gene_ID type gene_symbol  \
# 0   2881032.0  ECB_02693  cds        yqeG
# 1   4065973.0  ECB_03781  cds        yiiG
# 2   4316271.0  ECB_03987  cds        adiY
# 3   1468609.0  ECB_01382  cds         NaN
# 4   2392940.0  ECB_02257  cds        yfcO
# 5   4437424.0  ECB_04099  cds        yjfF
# 6    791672.0  ECB_00732  cds         NaN
# 7   3789895.0  ECB_03531  cds         NaN
# 8   3119814.0  ECB_02915  cds        ygiL
# 9   3584927.0  ECB_03356  cds        yhiD
# 10  2364812.0  ECB_02227  cds        yfcG
# 11    67901.0  ECB_00062  cds        polB
# 12   510038.0  ECB_00461  cds        allP
# 13  3493672.0  ECB_03279  cds         NaN
# 14  3198194.0  ECB_02984  cds        tdcB
# 15  2791651.0  ECB_02620  cds        ygcE
# 16   157515.0  ECB_00138  cds        htrE
# 17  3861756.0  ECB_03604  cds        yieC
# 18  3124250.0  ECB_02918  cds        yqiI
# 19  3820394.0  ECB_03564  cds        yidL
# 20  3738702.0  ECB_03480  cds        waaV
# 21  4481693.0  ECB_04137  cds        yjgW
# 22  2137401.0  ECB_02030  cds        yegX
# 23   482314.0  ECB_00435  cds        copA
# 24   571527.0  ECB_00529  cds         NaN
# 25  1604828.0  ECB_01508  cds        stfR
# 26   892072.0  ECB_00832  cds         NaN
# 27   291093.0  ECB_00259  cds        ykgI
# 28   628752.0  ECB_00581  cds        citG
# 29  4285300.0  ECB_03955  cds        yjcS
# 30  3122107.0  ECB_02916  cds        yqiG
# 31   782643.0  ECB_00723  cds        ybhI
# 32  2118115.0  ECB_02004  cds         NaN
# 33  4390294.0  ECB_04051  cds        yjfL
# 34  3861130.0  ECB_03604  cds        yieC
# 35  2209778.0  ECB_02095  cds        yeiC
# 36  1017699.0  ECB_00944  cds        ycbS
# 37  3790107.0  ECB_03531  cds         NaN
# 38  1423353.0  ECB_01342  cds         NaN
# 39   797173.0  ECB_00738  cds         NaN
# 40   697884.0  ECB_00646  cds        ybfP
# 41  3793772.0  ECB_03536  cds        insI
# 42  1617822.0  ECB_01528  cds         NaN
# 43  3028121.0  ECB_02828  cds         NaN
# 44  2316059.0  ECB_02181  cds        yfbG
# 45  3866784.0  ECB_03607  cds        bglG
# 46   154561.0  ECB_00136  cds        yadL
# 47  4305975.0  ECB_03980  cds        yjdA
# 48  4527702.0  ECB_04186  cds        fimD
# 49  4041604.0  ECB_03759  cds        yihN
#
#                                           description
# 0                               predicted transporter
# 1                                hypothetical protein
# 2               DNA-binding transcriptional activator
# 3                                hypothetical protein
# 4                                hypothetical protein
# 5                 predicted sugar transporter subunit
# 6                      conserved hypothetical protein
# 7                                hypothetical protein
# 8             predicted fimbrial-like adhesin protein
# 9   predicted Mg(2+) transport ATPase inner membra...
# 10                predicted glutathione S-transferase
# 11                                  DNA polymerase II
# 12                    predicted allantoin transporter
# 13                               hypothetical protein
# 14                              threonine dehydratase
# 15                                   predicted kinase
# 16             predicted outer membrane usher protein
# 17  carbohydrate-specific outer membrane porin, cr...
# 18                               hypothetical protein
# 19    predicted DNA-binding transcriptional regulator
# 20               putative beta1,3-glucosyltransferase
# 21                                  predicted protein
# 22                                predicted hydrolase
# 23                                 copper transporter
# 24                               hypothetical protein
# 25                       predicted tail fiber protein
# 26                     probable capsid portal protein
# 27                               hypothetical protein
# 28        triphosphoribosyl-dephospho-CoA transferase
# 29                          predicted alkyl sulfatase
# 30             predicted outer membrane usher protein
# 31                              predicted transporter
# 32                         Replication gene A protein
# 33                   conserved inner membrane protein
# 34  carbohydrate-specific outer membrane porin, cr...
# 35                                   predicted kinase
# 36             predicted outer membrane usher protein
# 37                               hypothetical protein
# 38                     conserved hypothetical protein
# 39                               hypothetical protein
# 40                               hypothetical protein
# 41                                   IS30 transposase
# 42             antitermination protein Q-like protein
# 43             Polysialic acid transport protein kpsM
# 44                               hypothetical protein
# 45   transcriptional antiterminator of the bgl operon
# 46            predicted fimbrial-like adhesin protein
# 47  conserved hypothetical protein with nucleoside...
# 48  outer membrane usher protein, type 1 fimbrial ...
# 49                              predicted transporter

# %%
#dictionary with days and corresponding Rtot
RtotS2_dict = dict(zip(r_totS2.columns.values, r_totS2.iloc[0].values))

dfS2_freqs = dfS2_dropped.copy() #df with freqs of all days

def frequency(df_freqs, rtot):
    for day in ["0_1","0_2","1","2","3","4"]:
        freq_vals = [] #all frequency values
        for count in df_freqs[day]:
            freq = count/rtot[day]
            freq_vals.append(freq)
        df_freqs["%s_freq" % day] = freq_vals
    df_freqs.insert(15, "0_freq", df_freqs[["0_1_freq", "0_2_freq"]].mean(axis=1))
    
frequency(dfS2_freqs, RtotS2_dict)
dfS2_freqs.head(50)
# Out:
#     level_0  index               barcode  0_1  0_2    1    2    3   4 strand  \
# 0         1     35  CCTAAGCGCTTACCCCAACC   42  116   10   53   10  23      +
# 1         2     36  TCGGACCCAGCTTGGAATAA   48  107  104   69   52  91      +
# 2         5     43  CAGTCCCGGCCCCGCTGCGC   32   78   39   14    4  31      -
# 3         6     44  ATTCCTGTTACTAGATCAAA   34   97   29   26   24  30      +
# 4         7     46  CCCCCCAGGCTCGTGACGCC   65   61   61   45   51  53      -
# 5         9     49  GCCACAGCACCGGTCACACT   42   53   39   73   12  33      -
# 6        11     52  AAAATTAATTAGTCGCACGA   17   43   24   34   48  19      -
# 45      127    225  GCCCATTCCCCATCACCTCG   64   66   65   88   70  94      -
# 46      128    226  CTCCCCCCCGGTCCCGCCCT   32   80   30   50    7  15      -
# 47      156    267  AAAGCCCCGCTCCCTCGCCG   43   51   33   71   28  29      +
# 48      160    271  GAACGCCCGGATCACCCACC   27   37   11   56   26  28      +
# 49      162    274  ACGCACTCGCACCAGAAGGC   58   49   52   67   59  23      +
#
#     ...  type gene_symbol                                        description  \
# 0   ...   cds        yqeG                              predicted transporter
# 1   ...   cds        yiiG                               hypothetical protein
# 2   ...   cds        adiY              DNA-binding transcriptional activator
# 3   ...   cds         NaN                               hypothetical protein
# 4   ...   cds        yfcO                               hypothetical protein
# 5   ...   cds        yjfF                predicted sugar transporter subunit
# 6   ...   cds         NaN                     conserved hypothetical protein
# 7   ...   cds         NaN                               hypothetical protein
# 8   ...   cds        ygiL            predicted fimbrial-like adhesin protein
# 9   ...   cds        yhiD  predicted Mg(2+) transport ATPase inner membra...
# 10  ...   cds        yfcG                predicted glutathione S-transferase
# 11  ...   cds        polB                                  DNA polymerase II
# 12  ...   cds        allP                    predicted allantoin transporter
# 13  ...   cds         NaN                               hypothetical protein
# 14  ...   cds        tdcB                              threonine dehydratase
# 15  ...   cds        ygcE                                   predicted kinase
# 16  ...   cds        htrE             predicted outer membrane usher protein
# 17  ...   cds        yieC  carbohydrate-specific outer membrane porin, cr...
# 18  ...   cds        yqiI                               hypothetical protein
# 19  ...   cds        yidL    predicted DNA-binding transcriptional regulator
# 20  ...   cds        waaV               putative beta1,3-glucosyltransferase
# 21  ...   cds        yjgW                                  predicted protein
# 22  ...   cds        yegX                                predicted hydrolase
# 23  ...   cds        copA                                 copper transporter
# 24  ...   cds         NaN                               hypothetical protein
# 25  ...   cds        stfR                       predicted tail fiber protein
# 26  ...   cds         NaN                     probable capsid portal protein
# 27  ...   cds        ykgI                               hypothetical protein
# 28  ...   cds        citG        triphosphoribosyl-dephospho-CoA transferase
# 29  ...   cds        yjcS                          predicted alkyl sulfatase
# 30  ...   cds        yqiG             predicted outer membrane usher protein
# 31  ...   cds        ybhI                              predicted transporter
# 32  ...   cds         NaN                         Replication gene A protein
# 33  ...   cds        yjfL                   conserved inner membrane protein
# 34  ...   cds        yieC  carbohydrate-specific outer membrane porin, cr...
# 35  ...   cds        yeiC                                   predicted kinase
# 36  ...   cds        ycbS             predicted outer membrane usher protein
# 37  ...   cds         NaN                               hypothetical protein
# 38  ...   cds         NaN                     conserved hypothetical protein
# 39  ...   cds         NaN                               hypothetical protein
# 40  ...   cds        ybfP                               hypothetical protein
# 41  ...   cds        insI                                   IS30 transposase
# 42  ...   cds         NaN             antitermination protein Q-like protein
# 43  ...   cds         NaN             Polysialic acid transport protein kpsM
# 44  ...   cds        yfbG                               hypothetical protein
# 45  ...   cds        bglG   transcriptional antiterminator of the bgl operon
# 46  ...   cds        yadL            predicted fimbrial-like adhesin protein
# 47  ...   cds        yjdA  conserved hypothetical protein with nucleoside...
# 48  ...   cds        fimD  outer membrane usher protein, type 1 fimbrial ...
# 49  ...   cds        yihN                              predicted transporter
# 35  0.000004  4.262857e-06  0.000004  4.763344e-06  0.000003  6.613612e-07
# 36  0.000002  1.559582e-06  0.000002  2.428371e-06  0.000002  4.629529e-06
# 37  0.000003  4.574773e-06  0.000001  3.455759e-06  0.000004  3.857940e-06
# 38  0.000004  4.990662e-06  0.000003  3.268962e-06  0.000003  5.290890e-06
# 39  0.000005  6.134355e-06  0.000004  4.856743e-06  0.000005  7.715881e-06
# 40  0.000007  5.510522e-06  0.000008  3.268962e-06  0.000001  4.629529e-06
# 41  0.000013  1.434815e-05  0.000012  1.251545e-05  0.000005  1.454995e-05
# 42  0.000004  3.015191e-06  0.000004  5.323737e-06  0.000007  5.731797e-06
# 43  0.000004  4.366829e-06  0.000003  4.576546e-06  0.000007  1.289654e-05
# 44  0.000005  6.862160e-06  0.000003  5.884131e-06  0.000005  1.069201e-05
# 45  0.000006  6.654216e-06  0.000006  6.070929e-06  0.000009  7.715881e-06
# 46  0.000005  3.327108e-06  0.000007  2.801967e-06  0.000005  7.715881e-07
# 47  0.000005  4.470801e-06  0.000005  3.082164e-06  0.000007  3.086352e-06
# 48  0.000003  2.807247e-06  0.000003  1.027388e-06  0.000006  2.865899e-06
# 49  0.000005  6.030383e-06  0.000005  4.856743e-06  0.000007  6.503385e-06
#
#       4_freq
# 0   0.000003
# 1   0.000014
# 2   0.000005
# 3   0.000004
# 4   0.000008
# 5   0.000005
# 6   0.000003
# 7   0.000003
# 8   0.000005
# 9   0.000005
# 10  0.000003
# 11  0.000000
# 12  0.000003
# 13  0.000003
# 14  0.000005
# 15  0.000000
# 16  0.000008
# 17  0.000003
# 18  0.000007
# 19  0.000006
# 20  0.000002
# 21  0.000004
# 22  0.000012
# 23  0.000002
# 24  0.000000
# 25  0.000004
# 26  0.000001
# 27  0.000012
# 28  0.000009
# 29  0.000004
# 30  0.000004
# 31  0.000006
# 32  0.000003
# 33  0.000007
# 34  0.000009
# 35  0.000005
# 36  0.000012
# 37  0.000003
# 38  0.000000
# 39  0.000006
# 40  0.000007
# 41  0.000014
# 42  0.000008
# 43  0.000002
# 44  0.000008
# 45  0.000014
# 46  0.000002
# 47  0.000004
# 48  0.000004
# 49  0.000003
#
# [50 rows x 22 columns]

# %%
dfS2_x = dfS2_freqs.copy() #df with freqs of VST (variance stabilizing transformation)

def x_freq(df_x):
    for freq in ["0_freq","1_freq","2_freq","3_freq","4_freq"]:
        x_vals = [] #all frequency values
        for count in df_x[freq]:
            count = np.sqrt(count)
            x_vals.append(count)
        df_x["x(%s)" % freq] = x_vals

df_S2 = x_freq(dfS2_x)  
dfS2_x = dfS2_x.drop(dfS2_x.columns[[0, 1, 3, 4, 5, 6, 7, 8, 15, 16, 17, 18, 19, 20, 21]], axis=1)
dfS2_x.head(50)
# Out:
#                  barcode strand        pos    gene_ID type gene_symbol  \
# 0   CCTAAGCGCTTACCCCAACC      +  2881032.0  ECB_02693  cds        yqeG
# 1   TCGGACCCAGCTTGGAATAA      +  4065973.0  ECB_03781  cds        yiiG
# 2   CAGTCCCGGCCCCGCTGCGC      -  4316271.0  ECB_03987  cds        adiY
# 3   ATTCCTGTTACTAGATCAAA      +  1468609.0  ECB_01382  cds         NaN
# 4   CCCCCCAGGCTCGTGACGCC      -  2392940.0  ECB_02257  cds        yfcO
# 5   GCCACAGCACCGGTCACACT      -  4437424.0  ECB_04099  cds        yjfF
# 6   AAAATTAATTAGTCGCACGA      -   791672.0  ECB_00732  cds         NaN
# 7   TTACCGACTACTCACATTGA      -  3789895.0  ECB_03531  cds         NaN
# 8   CGAACCCTCCGACGCGCTTT      -  3119814.0  ECB_02915  cds        ygiL
# 9   CCCGACATCGCACGCAACGC      +  3584927.0  ECB_03356  cds        yhiD
# 10  CCCTCACCCTATTATCTGCC      -  2364812.0  ECB_02227  cds        yfcG
# 11  GCTCACTACACAAACACGCC      +    67901.0  ECB_00062  cds        polB
# 12  TCGTCCCTGACCGTAGTCCA      -   510038.0  ECB_00461  cds        allP
# 13  TTGTCTAAATACGAGACGTC      -  3493672.0  ECB_03279  cds         NaN
# 14  CGTCCTGTCTCCAAACGAAA      +  3198194.0  ECB_02984  cds        tdcB
# 15  CACACTCAGAAAATCTGTTT      +  2791651.0  ECB_02620  cds        ygcE
# 16  CCACCAGTACCGATATCAGG      -   157515.0  ECB_00138  cds        htrE
# 17  CTCCCGCTCCGACACCTAAC      +  3861756.0  ECB_03604  cds        yieC
# 18  CCGGCTCTATTCTCCCACGC      +  3124250.0  ECB_02918  cds        yqiI
# 19  ATGGATAACATAAGCTAACA      +  3820394.0  ECB_03564  cds        yidL
# 20  CCCTCCCGGACTCTCCGACA      +  3738702.0  ECB_03480  cds        waaV
# 21  ATATCGTGGCAAGATCTGCA      -  4481693.0  ECB_04137  cds        yjgW
# 22  CTTTCCCCCAGACTCATCGA      -  2137401.0  ECB_02030  cds        yegX
# 23  GAATTCCGCCACAATGCGGC      +   482314.0  ECB_00435  cds        copA
# 24  CGCCTCATCGTCGATCCCCT      +   571527.0  ECB_00529  cds         NaN
# 25  CTCTCGTACAACTACCAACG      -  1604828.0  ECB_01508  cds        stfR
# 26  ACCCTCAGTCCGTCCGGTAT      +   892072.0  ECB_00832  cds         NaN
# 27  GCGGCGTCCCCCTGCCGCTC      -   291093.0  ECB_00259  cds        ykgI
# 28  TCACTTGCGTGCTTGCCAGT      +   628752.0  ECB_00581  cds        citG
# 29  TTTAATACCAACTTAAGCTT      +  4285300.0  ECB_03955  cds        yjcS
# 30  AAGACCCCAACCCAACAGCT      +  3122107.0  ECB_02916  cds        yqiG
# 31  GAATAACATCGATTCTACAC      +   782643.0  ECB_00723  cds        ybhI
# 32  CCAGGCAGCGACTGACCGCC      -  2118115.0  ECB_02004  cds         NaN
# 33  ACACTCGGCCCCGACGACGT      -  4390294.0  ECB_04051  cds        yjfL
# 34  ATTCCAAGCTTCTCCACATA      +  3861130.0  ECB_03604  cds        yieC
# 35  ATTTTTAGCATAATTACGTC      -  2209778.0  ECB_02095  cds        yeiC
# 36  TATAGCCTGGCATGACCGTA      +  1017699.0  ECB_00944  cds        ycbS
# 37  GTCCCATAGAATTGAACACC      -  3790107.0  ECB_03531  cds         NaN
# 38  GTCCTCTTGCGCTCCACAAC      -  1423353.0  ECB_01342  cds         NaN
# 39  CCGCCCGACCCAAAACCCAC      +   797173.0  ECB_00738  cds         NaN
# 40  GTCGCGATACTTACCCGCAT      +   697884.0  ECB_00646  cds        ybfP
# 41  CCCTACCAGGCCACACCCCT      +  3793772.0  ECB_03536  cds        insI
# 42  TCTGCCCTAGTGCGACCTTA      -  1617822.0  ECB_01528  cds         NaN
# 43  CGCTAGGCTGTGAGTCCGTA      +  3028121.0  ECB_02828  cds         NaN
# 44  CCCTGTACGGCTTGTTCCAC      -  2316059.0  ECB_02181  cds        yfbG
# 45  GCCCATTCCCCATCACCTCG      -  3866784.0  ECB_03607  cds        bglG
# 46  CTCCCCCCCGGTCCCGCCCT      -   154561.0  ECB_00136  cds        yadL
# 47  AAAGCCCCGCTCCCTCGCCG      +  4305975.0  ECB_03980  cds        yjdA
# 48  GAACGCCCGGATCACCCACC      +  4527702.0  ECB_04186  cds        fimD
# 49  ACGCACTCGCACCAGAAGGC      +  4041604.0  ECB_03759  cds        yihN
#
#                                           description  x(0_freq)  x(1_freq)  \
# 0                               predicted transporter   0.002744   0.000966
# 1                                hypothetical protein   0.002725   0.003117
# 2               DNA-binding transcriptional activator   0.002293   0.001909
# 3                                hypothetical protein   0.002498   0.001646
# 4                                hypothetical protein   0.002488   0.002387
# 5                 predicted sugar transporter subunit   0.002151   0.001909
# 6                      conserved hypothetical protein   0.001693   0.001497
# 7                                hypothetical protein   0.002163   0.002347
# 8             predicted fimbrial-like adhesin protein   0.001576   0.001756
# 9   predicted Mg(2+) transport ATPase inner membra...   0.002595   0.002004
# 10                predicted glutathione S-transferase   0.001915   0.001528
# 11                                  DNA polymerase II   0.001580   0.002246
# 12                    predicted allantoin transporter   0.001386   0.002647
# 13                               hypothetical protein   0.001201   0.002647
# 14                              threonine dehydratase   0.002059   0.002699
# 15                                   predicted kinase   0.002271   0.001466
# 16             predicted outer membrane usher protein   0.002021   0.002593
# 17  carbohydrate-specific outer membrane porin, cr...   0.001898   0.001332
# 18                               hypothetical protein   0.002736   0.002027
# 19    predicted DNA-binding transcriptional regulator   0.002101   0.002139
# 20               putative beta1,3-glucosyltransferase   0.002264   0.002801
# 21                                  predicted protein   0.002173   0.002716
# 22                                predicted hydrolase   0.002117   0.001466
# 23                                 copper transporter   0.002405   0.002647
# 24                               hypothetical protein   0.003960   0.002851
# 25                       predicted tail fiber protein   0.001791   0.000917
# 26                     probable capsid portal protein   0.002725   0.002751
# 27                               hypothetical protein   0.004270   0.003458
# 28        triphosphoribosyl-dephospho-CoA transferase   0.001657   0.001859
# 29                          predicted alkyl sulfatase   0.001935   0.002004
# 30             predicted outer membrane usher protein   0.001264   0.000000
# 31                              predicted transporter   0.002545   0.003938
# 32                         Replication gene A protein   0.001906   0.001646
# 33                   conserved inner membrane protein   0.002259   0.002931
# 34  carbohydrate-specific outer membrane porin, cr...   0.001720   0.001981
# 35                                   predicted kinase   0.002017   0.002183
df_t_xbar.head()
# Out:
#    Unnamed: 0  Day label      xbar    stderr       gens
# 0           0          1  0.010076  0.000367   6.643856
# 1           1          2  0.005077  0.000217  13.287712
# 2           2          3  0.004121  0.000169  19.931569
# 3           3          4  0.003196  0.000147  26.575425

# %%
tS2_dict = dict(zip(df_t_xbar["Day label"], df_t_xbar["gens"]))
xbarS2_dict = dict(zip(df_t_xbar["Day label"], df_t_xbar["xbar"]))
sS2_dict = dict(zip(df_s["gene_ID"], df_s["s"]))

print(tS2_dict)
print(xbarS2_dict)
# Out:
# {1: 6.64385619, 2: 13.28771238, 3: 19.93156857, 4: 26.57542476}
# {1: 0.0100757689833971, 2: 0.0050768578645267685, 3: 0.004120548332960537, 4: 0.0031961958810918767}

# %%
dfS2_x_corr = dfS2_x.copy()

#dropping rows/gene_IDs with no "s" value
no_s = []
for i in range(len(dfS2_x_corr)):
    index_gene = dfS2_x_corr.columns.get_loc("gene_ID")
    if dfS2_x_corr.iloc[i,index_gene] not in sS2_dict.keys():
        no_s.append(i)
dfS2_x_corr.drop(no_s, axis=0, inplace=True)
dfS2_x_corr = dfS2_x_corr.reset_index()
dfS2_x_corr = dfS2_x_corr.drop(dfS2_x_corr.columns[[0]], axis=1)

#calculating x_corrected
days = [1, 2, 3, 4]
x_freqs = ["x(1_freq)","x(2_freq)","x(3_freq)","x(4_freq)"]

def x_corr_form(day, x, s_dict, t_dict, xbar_dict, df_x_corr):
    x_corr_vals = []
    for i in range(len(df_x_corr)):
        #index = day-1
        index_0 = df_x_corr.columns.get_loc("x(0_freq)")
        index_t = df_x_corr.columns.get_loc(x)
        x_0 = df_x_corr.iloc[i, index_0]
        x_t = df_x_corr.iloc[i, index_t]
        index_gene = df_x_corr.columns.get_loc("gene_ID")
        gene_ID = df_x_corr.iloc[i, index_gene]
        if gene_ID in s_dict.keys():
            s = s_dict[gene_ID]
        else:
            continue;
        t = t_dict[day]
        xbar = xbar_dict[day]
        x_corr = x_corr_ele(x_0, x_t, s, xbar, t)
        x_corr_vals.append(x_corr)
    return x_corr_vals
        
def x_corr_ele(x_0, x_t, s, xbar, t):
    x_corr = x_t - (x_0*math.exp((s-xbar)* (t/2)))
    return x_corr

#x_corr
for day, x in zip(days, x_freqs):
    x_corr = x_corr_form(day, x, sS2_dict, tS2_dict, xbarS2_dict, dfS2_x_corr)
    dfS2_x_corr["x_corr(%s)" % day] = x_corr
    
print(len(dfS2_x_corr))
dfS2_x_corr.head(50)
# Out:
# 46712
#                  barcode strand        pos    gene_ID type gene_symbol  \
# 0   CCTAAGCGCTTACCCCAACC      +  2881032.0  ECB_02693  cds        yqeG
# 1   TCGGACCCAGCTTGGAATAA      +  4065973.0  ECB_03781  cds        yiiG
# 2   CAGTCCCGGCCCCGCTGCGC      -  4316271.0  ECB_03987  cds        adiY
# 3   CCCCCCAGGCTCGTGACGCC      -  2392940.0  ECB_02257  cds        yfcO
# 4   GCCACAGCACCGGTCACACT      -  4437424.0  ECB_04099  cds        yjfF
# 5   CGAACCCTCCGACGCGCTTT      -  3119814.0  ECB_02915  cds        ygiL
# 6   CCCGACATCGCACGCAACGC      +  3584927.0  ECB_03356  cds        yhiD
# 7   CCCTCACCCTATTATCTGCC      -  2364812.0  ECB_02227  cds        yfcG
# 8   GCTCACTACACAAACACGCC      +    67901.0  ECB_00062  cds        polB
# 9   TCGTCCCTGACCGTAGTCCA      -   510038.0  ECB_00461  cds        allP
# 10  CGTCCTGTCTCCAAACGAAA      +  3198194.0  ECB_02984  cds        tdcB
# 11  CACACTCAGAAAATCTGTTT      +  2791651.0  ECB_02620  cds        ygcE
# 12  CCACCAGTACCGATATCAGG      -   157515.0  ECB_00138  cds        htrE
# 13  CTCCCGCTCCGACACCTAAC      +  3861756.0  ECB_03604  cds        yieC
# 14  CCGGCTCTATTCTCCCACGC      +  3124250.0  ECB_02918  cds        yqiI
# 15  ATGGATAACATAAGCTAACA      +  3820394.0  ECB_03564  cds        yidL
# 16  CCCTCCCGGACTCTCCGACA      +  3738702.0  ECB_03480  cds        waaV
# 17  ATATCGTGGCAAGATCTGCA      -  4481693.0  ECB_04137  cds        yjgW
# 18  CTTTCCCCCAGACTCATCGA      -  2137401.0  ECB_02030  cds        yegX
# 19  GAATTCCGCCACAATGCGGC      +   482314.0  ECB_00435  cds        copA
# 20  CTCTCGTACAACTACCAACG      -  1604828.0  ECB_01508  cds        stfR
# 21  GCGGCGTCCCCCTGCCGCTC      -   291093.0  ECB_00259  cds        ykgI
# 22  TCACTTGCGTGCTTGCCAGT      +   628752.0  ECB_00581  cds        citG
# 23  TTTAATACCAACTTAAGCTT      +  4285300.0  ECB_03955  cds        yjcS
# 24  AAGACCCCAACCCAACAGCT      +  3122107.0  ECB_02916  cds        yqiG
# 25  GAATAACATCGATTCTACAC      +   782643.0  ECB_00723  cds        ybhI
# 26  ACACTCGGCCCCGACGACGT      -  4390294.0  ECB_04051  cds        yjfL
# 27  ATTCCAAGCTTCTCCACATA      +  3861130.0  ECB_03604  cds        yieC
# 28  ATTTTTAGCATAATTACGTC      -  2209778.0  ECB_02095  cds        yeiC
# 29  TATAGCCTGGCATGACCGTA      +  1017699.0  ECB_00944  cds        ycbS
# 30  GTCGCGATACTTACCCGCAT      +   697884.0  ECB_00646  cds        ybfP
# 31  CCCTACCAGGCCACACCCCT      +  3793772.0  ECB_03536  cds        insI
# 32  CCCTGTACGGCTTGTTCCAC      -  2316059.0  ECB_02181  cds        yfbG
# 33  GCCCATTCCCCATCACCTCG      -  3866784.0  ECB_03607  cds        bglG
# 34  CTCCCCCCCGGTCCCGCCCT      -   154561.0  ECB_00136  cds        yadL
# 35  AAAGCCCCGCTCCCTCGCCG      +  4305975.0  ECB_03980  cds        yjdA
# 36  GAACGCCCGGATCACCCACC      +  4527702.0  ECB_04186  cds        fimD
# 37  ACGCACTCGCACCAGAAGGC      +  4041604.0  ECB_03759  cds        yihN
# 38  TACTACTCGGACCAAGTAGC      -  2006185.0  ECB_01904  cds        insD
# 39  TCTATGATGTTGCGTGGAGC      -  3729902.0  ECB_03473  cds        yibD
# 40  CGTTCAAACTCTCTTCATCG      -  2662350.0  ECB_02490  cds        aroF
# 41  CTTTCAAGTCCTGGCGGAAC      +   639220.0  ECB_00592  cds        crcA
# 42  TATCGCCAAATCACTTCTAA      +  1247412.0  ECB_01172  cds        treA
# 43  CCACACAGTACATACCTGAC      +   294496.0  ECB_00262  cds        ykgE
# 44  TCCAGCACCCTATTAGCACT      -  1552702.0  ECB_01454  cds        yddA
# 45  ATTCCCTTCTTAGTGTGCAT      +  2162109.0  ECB_02051  cds        yehQ
# 46  AGCAGAGGGCCAACGTACCT      -  1083900.0  ECB_01007  cds        wrbA
# 47  CCCTACTCCCCCTCCGGCCG      -  1989447.0  ECB_01891  cds        yeeJ
# 48  GGCGAAATCGTACCCTCAAT      +   543122.0  ECB_00495  cds        ybcL
# 49  GATCCTTGCTCCCGCCCTCC      +  3675138.0  ECB_03429  cds        yiaM
#
#                                           description  x(0_freq)  x(1_freq)  \
# 0                               predicted transporter   0.002744   0.000966
# 1                                hypothetical protein   0.002725   0.003117
# 2               DNA-binding transcriptional activator   0.002293   0.001909
# 3                                hypothetical protein   0.002488   0.002387
# 4                 predicted sugar transporter subunit   0.002151   0.001909
# 5             predicted fimbrial-like adhesin protein   0.001576   0.001756
# 6   predicted Mg(2+) transport ATPase inner membra...   0.002595   0.002004
# 7                 predicted glutathione S-transferase   0.001915   0.001528
# 8                                   DNA polymerase II   0.001580   0.002246
# 9                     predicted allantoin transporter   0.001386   0.002647
# 10                              threonine dehydratase   0.002059   0.002699
# 11                                   predicted kinase   0.002271   0.001466
# 12             predicted outer membrane usher protein   0.002021   0.002593
# 13  carbohydrate-specific outer membrane porin, cr...   0.001898   0.001332
# 14                               hypothetical protein   0.002736   0.002027
# 15    predicted DNA-binding transcriptional regulator   0.002101   0.002139
# 16               putative beta1,3-glucosyltransferase   0.002264   0.002801
# 17                                  predicted protein   0.002173   0.002716
# 18                                predicted hydrolase   0.002117   0.001466
# 19                                 copper transporter   0.002405   0.002647
# 20                       predicted tail fiber protein   0.001791   0.000917
# 21                               hypothetical protein   0.004270   0.003458
# 22        triphosphoribosyl-dephospho-CoA transferase   0.001657   0.001859
# 23                          predicted alkyl sulfatase   0.001935   0.002004
# 24             predicted outer membrane usher protein   0.001264   0.000000
# 25                              predicted transporter   0.002545   0.003938
# 26                   conserved inner membrane protein   0.002259   0.002931
# 27  carbohydrate-specific outer membrane porin, cr...   0.001720   0.001981
# 28                                   predicted kinase   0.002017   0.002183
# 29             predicted outer membrane usher protein   0.001250   0.001558
# 30                               hypothetical protein   0.002619   0.001808
# 31                                   IS30 transposase   0.003628   0.003538
# 32                               hypothetical protein   0.002266   0.002426
# 33   transcriptional antiterminator of the bgl operon   0.002524   0.002464
# 34            predicted fimbrial-like adhesin protein   0.002313   0.001674
# 35  conserved hypothetical protein with nucleoside...   0.002141   0.001756
# 36  outer membrane usher protein, type 1 fimbrial ...   0.001763   0.001014
# 37                              predicted transporter   0.002296   0.002204
# 38           IS2 insertion element transposase InsAB'   0.002943   0.002751
# 34   0.002221   0.000878   0.001493  -0.000548   0.000014  -0.001297
# 35   0.002646   0.001757   0.002077  -0.000321   0.000564  -0.000317
# 36   0.002350   0.001693   0.002040  -0.000670   0.000688   0.000063
# 37   0.002571   0.002550   0.001849  -0.000002   0.000381   0.000391
# 38   0.000888   0.000000   0.000386   0.000334  -0.001163  -0.001729
# 39   0.003029   0.003320   0.003817  -0.000026   0.000104   0.000448
# 40   0.003440   0.003785   0.002962   0.000205   0.001077   0.001428
# 41   0.002913   0.001521   0.001443  -0.000134   0.000545  -0.000797
# 42   0.001884   0.002126   0.001767  -0.000353   0.000020   0.000291
# 43   0.002011   0.002276   0.002834   0.000623  -0.000278   0.000008
# 44   0.002453   0.003219   0.003012  -0.001033  -0.000842  -0.000028
# 45   0.002286   0.002047   0.001724   0.001105   0.000853   0.000659
# 46   0.002329   0.001521   0.001219  -0.000259   0.000379  -0.000329
# 47   0.003109   0.002252   0.002147  -0.000305   0.000788  -0.000042
# 48   0.001961   0.002656   0.002408   0.000113   0.000152   0.000894
# 49   0.001858   0.002697   0.001849  -0.000347  -0.000404   0.000445
#
#        x_corr(4)
# 0  -8.158716e-04
# 1   1.247525e-03
# 2   2.616732e-06
# 3   4.558821e-04
# 4   4.612418e-05
# 5   9.170245e-04
# 6  -1.663410e-04
# 7   8.853711e-06
# 8  -1.464617e-03
# 9   3.989621e-04
# 10  2.861532e-04
# 11 -2.014993e-03
# 12  9.217565e-04
# 13  3.412121e-05
# 14  1.787899e-04
# 15  3.986019e-04
# 16 -5.709997e-04
# 17  2.114313e-04
# 18  1.389142e-03
# 19 -2.997287e-04
# 20  3.656658e-04
# 21 -1.556996e-04
# 22  1.096861e-03
# 23  1.122175e-04
# 24  7.282549e-04
# 25  1.786609e-05
# 26  5.583062e-04
# 27  1.466102e-03
# 28  2.648657e-04
# 29  2.195249e-03
# 30  9.987196e-05
# 31  2.689300e-04
# 32  5.708257e-04
# 33  1.381107e-03
# 34 -6.642668e-04
# 35 -3.655567e-07
# 36  4.326781e-04
# 37 -2.921760e-04
# 38 -1.079853e-03
# 39  9.805831e-04
# 40  5.954448e-04
# 41 -8.408751e-04
# 42 -4.937349e-05
# 43  5.715575e-04
# 44 -2.069853e-04
# 45  3.726408e-04
# 46 -5.460915e-04
# 47 -1.341830e-04
# 48  6.818870e-04
# 49 -4.063124e-04

# %%
#list of all x_corr(t) for each barcode:
xS2_corrs = dfS2_x_corr[["x_corr(1)","x_corr(2)","x_corr(3)","x_corr(4)"]].values.tolist()

def x_var(x_corrs, df_x_corr):
    x_c_var = []
    for x_c in x_corrs:
        x_var = np.var(x_c)
        x_c_var.append(x_var)
    df_x_corr["var(x_corr)"] = x_c_var

x_var(xS2_corrs, dfS2_x_corr)
dfS2_x_corr.head(50)
# Out:
#                  barcode strand        pos    gene_ID type gene_symbol  \
# 0   CCTAAGCGCTTACCCCAACC      +  2881032.0  ECB_02693  cds        yqeG
# 1   TCGGACCCAGCTTGGAATAA      +  4065973.0  ECB_03781  cds        yiiG
# 2   CAGTCCCGGCCCCGCTGCGC      -  4316271.0  ECB_03987  cds        adiY
# 3   CCCCCCAGGCTCGTGACGCC      -  2392940.0  ECB_02257  cds        yfcO
# 4   GCCACAGCACCGGTCACACT      -  4437424.0  ECB_04099  cds        yjfF
# 5   CGAACCCTCCGACGCGCTTT      -  3119814.0  ECB_02915  cds        ygiL
# 6   CCCGACATCGCACGCAACGC      +  3584927.0  ECB_03356  cds        yhiD
# 7   CCCTCACCCTATTATCTGCC      -  2364812.0  ECB_02227  cds        yfcG
# 8   GCTCACTACACAAACACGCC      +    67901.0  ECB_00062  cds        polB
# 9   TCGTCCCTGACCGTAGTCCA      -   510038.0  ECB_00461  cds        allP
# 10  CGTCCTGTCTCCAAACGAAA      +  3198194.0  ECB_02984  cds        tdcB
# 11  CACACTCAGAAAATCTGTTT      +  2791651.0  ECB_02620  cds        ygcE
# 12  CCACCAGTACCGATATCAGG      -   157515.0  ECB_00138  cds        htrE
# 13  CTCCCGCTCCGACACCTAAC      +  3861756.0  ECB_03604  cds        yieC
# 14  CCGGCTCTATTCTCCCACGC      +  3124250.0  ECB_02918  cds        yqiI
# 15  ATGGATAACATAAGCTAACA      +  3820394.0  ECB_03564  cds        yidL
# 16  CCCTCCCGGACTCTCCGACA      +  3738702.0  ECB_03480  cds        waaV
# 17  ATATCGTGGCAAGATCTGCA      -  4481693.0  ECB_04137  cds        yjgW
# 18  CTTTCCCCCAGACTCATCGA      -  2137401.0  ECB_02030  cds        yegX
# 19  GAATTCCGCCACAATGCGGC      +   482314.0  ECB_00435  cds        copA
# 20  CTCTCGTACAACTACCAACG      -  1604828.0  ECB_01508  cds        stfR
# 21  GCGGCGTCCCCCTGCCGCTC      -   291093.0  ECB_00259  cds        ykgI
# 22  TCACTTGCGTGCTTGCCAGT      +   628752.0  ECB_00581  cds        citG
# 23  TTTAATACCAACTTAAGCTT      +  4285300.0  ECB_03955  cds        yjcS
# 24  AAGACCCCAACCCAACAGCT      +  3122107.0  ECB_02916  cds        yqiG
# 25  GAATAACATCGATTCTACAC      +   782643.0  ECB_00723  cds        ybhI
# 26  ACACTCGGCCCCGACGACGT      -  4390294.0  ECB_04051  cds        yjfL
# 27  ATTCCAAGCTTCTCCACATA      +  3861130.0  ECB_03604  cds        yieC
# 28  ATTTTTAGCATAATTACGTC      -  2209778.0  ECB_02095  cds        yeiC
# 29  TATAGCCTGGCATGACCGTA      +  1017699.0  ECB_00944  cds        ycbS
# 30  GTCGCGATACTTACCCGCAT      +   697884.0  ECB_00646  cds        ybfP
# 31  CCCTACCAGGCCACACCCCT      +  3793772.0  ECB_03536  cds        insI
# 32  CCCTGTACGGCTTGTTCCAC      -  2316059.0  ECB_02181  cds        yfbG
# 33  GCCCATTCCCCATCACCTCG      -  3866784.0  ECB_03607  cds        bglG
# 34  CTCCCCCCCGGTCCCGCCCT      -   154561.0  ECB_00136  cds        yadL
# 35  AAAGCCCCGCTCCCTCGCCG      +  4305975.0  ECB_03980  cds        yjdA
# 36  GAACGCCCGGATCACCCACC      +  4527702.0  ECB_04186  cds        fimD
# 37  ACGCACTCGCACCAGAAGGC      +  4041604.0  ECB_03759  cds        yihN
# 38  TACTACTCGGACCAAGTAGC      -  2006185.0  ECB_01904  cds        insD
# 39  TCTATGATGTTGCGTGGAGC      -  3729902.0  ECB_03473  cds        yibD
# 40  CGTTCAAACTCTCTTCATCG      -  2662350.0  ECB_02490  cds        aroF
# 41  CTTTCAAGTCCTGGCGGAAC      +   639220.0  ECB_00592  cds        crcA
# 42  TATCGCCAAATCACTTCTAA      +  1247412.0  ECB_01172  cds        treA
# 43  CCACACAGTACATACCTGAC      +   294496.0  ECB_00262  cds        ykgE
# 44  TCCAGCACCCTATTAGCACT      -  1552702.0  ECB_01454  cds        yddA
# 45  ATTCCCTTCTTAGTGTGCAT      +  2162109.0  ECB_02051  cds        yehQ
# 46  AGCAGAGGGCCAACGTACCT      -  1083900.0  ECB_01007  cds        wrbA
# 47  CCCTACTCCCCCTCCGGCCG      -  1989447.0  ECB_01891  cds        yeeJ
# 48  GGCGAAATCGTACCCTCAAT      +   543122.0  ECB_00495  cds        ybcL
# 49  GATCCTTGCTCCCGCCCTCC      +  3675138.0  ECB_03429  cds        yiaM
#
#                                           description  x(0_freq)  x(1_freq)  \
# 0                               predicted transporter   0.002744   0.000966
# 1                                hypothetical protein   0.002725   0.003117
# 2               DNA-binding transcriptional activator   0.002293   0.001909
# 3                                hypothetical protein   0.002488   0.002387
# 4                 predicted sugar transporter subunit   0.002151   0.001909
# 5             predicted fimbrial-like adhesin protein   0.001576   0.001756
# 6   predicted Mg(2+) transport ATPase inner membra...   0.002595   0.002004
# 7                 predicted glutathione S-transferase   0.001915   0.001528
# 8                                   DNA polymerase II   0.001580   0.002246
# 9                     predicted allantoin transporter   0.001386   0.002647
# 10                              threonine dehydratase   0.002059   0.002699
# 11                                   predicted kinase   0.002271   0.001466
# 12             predicted outer membrane usher protein   0.002021   0.002593
# 13  carbohydrate-specific outer membrane porin, cr...   0.001898   0.001332
# 14                               hypothetical protein   0.002736   0.002027
# 15    predicted DNA-binding transcriptional regulator   0.002101   0.002139
# 16               putative beta1,3-glucosyltransferase   0.002264   0.002801
# 17                                  predicted protein   0.002173   0.002716
# 18                                predicted hydrolase   0.002117   0.001466
# 19                                 copper transporter   0.002405   0.002647
# 20                       predicted tail fiber protein   0.001791   0.000917
# 21                               hypothetical protein   0.004270   0.003458
# 22        triphosphoribosyl-dephospho-CoA transferase   0.001657   0.001859
# 23                          predicted alkyl sulfatase   0.001935   0.002004
# 24             predicted outer membrane usher protein   0.001264   0.000000
# 25                              predicted transporter   0.002545   0.003938
# 26                   conserved inner membrane protein   0.002259   0.002931
# 27  carbohydrate-specific outer membrane porin, cr...   0.001720   0.001981
# 28                                   predicted kinase   0.002017   0.002183
# 29             predicted outer membrane usher protein   0.001250   0.001558
# 30                               hypothetical protein   0.002619   0.001808
# 31                                   IS30 transposase   0.003628   0.003538
# 32                               hypothetical protein   0.002266   0.002426
# 33   transcriptional antiterminator of the bgl operon   0.002524   0.002464
# 39  9.805831e-04  1.516879e-07
# 40  5.954448e-04  2.160071e-07
# 41 -8.408751e-04  3.202406e-07
# 42 -4.937349e-05  5.250657e-08
# 43  5.715575e-04  1.445098e-07
# 44 -2.069853e-04  1.766724e-07
# 45  3.726408e-04  7.183130e-08
# 46 -5.460915e-04  1.186802e-07
# 47 -1.341830e-04  1.774988e-07
# 48  6.818870e-04  1.132467e-07
# 49 -4.063124e-04  1.300355e-07

# %%
#create df with variances and corresponding geneIDs
def list_genes(df_x_corr):
    updated_genes = []
    for gene in df_x_corr["gene_ID"].tolist():
        if gene not in updated_genes:
            updated_genes.append(gene)
    return updated_genes

#getting average variance of barcodes in each gene:
def avg_var(df_x_corr):
    avg_vars = []
    std_vars = []
    for gene in list_genes(df_x_corr):
        df_gene = df_x_corr.loc[df_x_corr["gene_ID"] == gene]
        x_vars = df_gene["var(x_corr)"].mean()
        avg_vars.append(x_vars)
        x_std = np.sqrt(x_vars)
        std_vars.append(x_std)
    return [avg_vars, std_vars]

bcS2_data = {"gene_ID": list_genes(dfS2_x_corr), "avg_var(x_corr)": avg_var(dfS2_x_corr)[0], "std(x_corr)": avg_var(dfS2_x_corr)[1]}
dfS2_bc = pd.DataFrame(bcS2_data)
dfS2_bc = dfS2_bc.sort_values(by = 'avg_var(x_corr)', ascending=[False])
dfS2_bc = dfS2_bc.reset_index() 
dfS2_bc.head(50)
# Out:
#     index    gene_ID  avg_var(x_corr)  std(x_corr)
# 0    1806  ECB_00941     8.706755e-07     0.000933
# 1     932  ECB_02357     7.954908e-07     0.000892
# 2    1187  ECB_00151     7.250337e-07     0.000851
# 3     838  ECB_01231     7.131319e-07     0.000844
# 4    1826  ECB_01937     6.932457e-07     0.000833
# 5    1151  ECB_00855     6.877596e-07     0.000829
# 6       7  ECB_02227     6.770863e-07     0.000823
# 7     806  ECB_03550     6.677832e-07     0.000817
# 8    1265  ECB_03877     6.580753e-07     0.000811
# 9     339  ECB_00583     6.524401e-07     0.000808
# 10    224  ECB_02505     6.484454e-07     0.000805
# 11   1466  ECB_00938     6.220665e-07     0.000789
# 12   1451  ECB_02259     6.212306e-07     0.000788
# 13    864  ECB_00413     6.155689e-07     0.000785
# 14   1765  ECB_02268     6.146351e-07     0.000784
# 15   1651  ECB_00367     6.079530e-07     0.000780
# 16   1459  ECB_01173     6.077182e-07     0.000780
# 17    353  ECB_03875     6.070214e-07     0.000779
# 18    418  ECB_01209     6.042640e-07     0.000777
# 19   1810  ECB_03990     5.989260e-07     0.000774
# 20   1057  ECB_00790     5.981263e-07     0.000773
# 21    503  ECB_03334     5.960078e-07     0.000772
# 22   1339  ECB_00316     5.955230e-07     0.000772
# 23   1679  ECB_01393     5.934825e-07     0.000770
# 24   1215  ECB_01747     5.933314e-07     0.000770
# 25   1648  ECB_01351     5.847507e-07     0.000765
# 26   1642  ECB_00997     5.823937e-07     0.000763
# 27   1767  ECB_01514     5.776032e-07     0.000760
# 28   1723  ECB_01858     5.774708e-07     0.000760
# 29     22  ECB_00581     5.757559e-07     0.000759
# 30   1436  ECB_02611     5.748075e-07     0.000758
# 31   1591  ECB_01355     5.740454e-07     0.000758
# 32   1602  ECB_00981     5.695315e-07     0.000755
# 33    417  ECB_00775     5.679649e-07     0.000754
# 34    114  ECB_02974     5.661680e-07     0.000752
# 35   1872  ECB_00317     5.640730e-07     0.000751
# 36   1413  ECB_01629     5.629538e-07     0.000750
# 37   1468  ECB_01627     5.624491e-07     0.000750
# 38   1795  ECB_03595     5.615474e-07     0.000749
# 39   1108  ECB_00306     5.596503e-07     0.000748
# 40    807  ECB_03982     5.584544e-07     0.000747
# 41     68  ECB_02520     5.528991e-07     0.000744
# 42   1328  ECB_03327     5.512079e-07     0.000742
# 43   1645  ECB_01387     5.510568e-07     0.000742
# 44    378  ECB_02187     5.508193e-07     0.000742
# 45    272  ECB_02644     5.442472e-07     0.000738
# 46   1551  ECB_03397     5.436450e-07     0.000737
# 47   1469  ECB_02556     5.428825e-07     0.000737
# 48    137  ECB_02293     5.428431e-07     0.000737
# 49   1861  ECB_00946     5.421142e-07     0.000736

# %%
dfS2_bc.to_csv('FS2.csv')

# %%
#first 3 genes with highest variance:
def plot_x(df_gene, gene_ID):
    for i in range(len(df_gene)):
        barcode = df_gene.iloc[i,0]
        x_array = df_gene.iloc[i,8:12].tolist()
        days = [1, 2, 3, 4]
        plt.plot(days, x_array)#, label = barcode)
        plt.xticks(np.arange(1,len(days)+1,1))
        plt.xlabel("Days")
        plt.ylabel("x(t)")
        plt.ylim([-0.02,0.02])
        #plt.legend()
        plt.title(gene_ID)
    plt.show()
    
def plot_x_corr(df_gene, gene_ID):
    for i in range(len(df_gene)):
        barcode = df_gene.iloc[i,0]
        x_array = df_gene.iloc[i,12:16].tolist()
        days = [1, 2, 3, 4]
        plt.plot(days, x_array)#, label = barcode)
        plt.xticks(np.arange(1,len(days)+1,1))
        plt.xlabel("Days")
        plt.ylabel("x_corr(t)")
        plt.ylim([-0.02,0.02])
        #plt.legend()
        plt.title(gene_ID)
    plt.show()

def plot_gene_x(gene_ID, df_x_corr):
    #gene_ID = df_bc.iloc[i, 1] #1 is index of gene_ID
    df_gene = df_x_corr.loc[df_x_corr["gene_ID"] == gene_ID]
    plot_x(df_gene, gene_ID)
    
def plot_gene_x_corr(gene_ID, df_x_corr):
    #gene_ID = df_bc.iloc[i, 1] #1 is index of gene_ID
    df_gene = df_x_corr.loc[df_x_corr["gene_ID"] == gene_ID]
    plot_x_corr(df_gene, gene_ID)
    
def plot_first(df_bc, df_x_corr, n): #number of first nth genes to plot for df_bc
    gene_order = df_bc["gene_ID"].tolist()
    for gene in gene_order[0:n]:
        plot_gene_x(gene, df_x_corr)
        plot_gene_x_corr(gene, df_x_corr)
        
def plot_last(df_bc, df_x_corr, n): #number of first nth genes to plot for df_bc
    gene_order = df_bc["gene_ID"].tolist()
    for gene in gene_order[-n:]:
        plot_gene_x(gene, df_x_corr)
        plot_gene_x_corr(gene, df_x_corr)

# %%
plot_first(dfS2_bc, dfS2_x_corr, 5)

# %%
plot_last(dfS2_bc, dfS2_x_corr, 3)
