# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import math

dfS1 = pd.read_csv('https://media.githubusercontent.com/media/joaoascensao/S-L-REL606-BarSeq/master/E_F/data/bc_counts/FS1_counts.csv')
r_totS1 = pd.read_csv('https://media.githubusercontent.com/media/joaoascensao/S-L-REL606-BarSeq/master/E_F/data/bc_counts/FS1_Rtot.csv')

gene_index = []
for gene in dfS1["gene_ID"]:
    gene_index.append(gene)
#df.index = gene_index
dfS1.dropna(subset = ["gene_ID"], inplace = True)
dfS1 = dfS1.reset_index() 

all_genes = [] #list of all gene_IDs
for gene in gene_index:
    if gene != "NaN" and gene != "nan" and gene not in all_genes:
        all_genes.append(gene)
all_genes.pop(0)
print(len(all_genes))
print(len(dfS1))

r_totS1 = r_totS1.iloc[: , 1:]
dfS1.head()
# Out:
# 3462
# 205801
#    index               barcode  0_1  0_2   1   2   3   4 strand        pos  \
# 0     34  GACTGGACTCTGACTACAAA   13   35  57  17  26   4      -   263938.0
# 1     35  CCTAAGCGCTTACCCCAACC   42  116  72  72  21  14      +  2881032.0
# 2     36  TCGGACCCAGCTTGGAATAA   48  107  75  68  60  41      +  4065973.0
# 3     37  TACCTCGGTCAAGGCGTCTA    8   35   0   7   0   0      -  2824332.0
# 4     40  TATGATTCACCTCTTTATAC   21   32  17  25  26  20      -  1790824.0
#
#      gene_ID type gene_symbol                            description
# 0  ECB_00238  cds        phoE  outer membrane phosphoporin protein E
# 1  ECB_02693  cds        yqeG                  predicted transporter
# 2  ECB_03781  cds        yiiG                   hypothetical protein
# 3  ECB_02648  cds         NaN          L-fuculose phosphate aldolase
# 4  ECB_01700  cds        cedA                cell division modulator

# %%
all_dfs = {} #dictionary of gene_ID to corresponding dataframe

for gene in all_genes:            
    all_dfs[gene] = dfS1[dfS1.gene_ID == gene]

# %%
RtotS1_dict = dict(zip(r_totS1.columns.values, r_totS1.iloc[0].values))

#days
days = [0, 1, 2, 3, 4]

#function that takes the frequency average of a column (for a certain day)
def avg_freq(df, day, Rtot_dict):
    freq_vals = [] #all frequency values
    for count in df[day]:
        freq = count/Rtot_dict[day]
        freq_vals.append(freq)
    avg = np.sum(freq_vals)/len(freq_vals) #avg of all frequency values
    return avg
    
#function that yields average frequency of all barcodes in a single gene over 5 days (0-4 days)
def freq_over_days(df, Rtot_dict):
    all_freqs = []
    for day in ["0_1","0_2","1","2","3","4"]:
        all_freqs.append(avg_freq(df, day, Rtot_dict))
    day0 = (all_freqs[0]+all_freqs[1])/2
    all_freqs.pop(0)
    all_freqs.pop(0)
    all_freqs.insert(0, day0)
    #print(all_freqs)
    return all_freqs

def plot_freq(freq_array, gene):
    days = [0, 1, 2, 3, 4]
    plt.plot(days, freq_array, label = gene)
    plt.xticks(np.arange(0,len(days),1))
    #plt.ylim([0.85e-5,1.1e-5])
    plt.xlabel("Days")
    plt.ylabel("Frequency")
    plt.legend()
    plt.title("Frequency plot of ECB_00522")
    
plot_freq(freq_over_days(all_dfs["ECB_00238"], RtotS1_dict),"ECB_00238")
plot_freq(freq_over_days(all_dfs["ECB_02693"], RtotS1_dict), "ECB_02693")
plot_freq(freq_over_days(all_dfs["ECB_01323"], RtotS1_dict),"ECB_01323")
plot_freq(freq_over_days(all_dfs["ECB_00522"], RtotS1_dict), "ECB_00522")

# %%
#discard of counts under an average of 40
def discard(df):
    to_discard = []
    for i in range(len(df)):
        sum = 0
        for day in ["0_1","0_2","1","2","3","4"]:
            sum += df.loc[i,day] 
        if sum/6 < 30: #average count across days is < 30 --> discard
            to_discard.append(i)
    return to_discard

dfS1_dropped = dfS1.copy()

dfS1_dropped.drop(labels=discard(dfS1), axis=0, inplace=True)
print(len(discard(dfS1)))
dfS1_dropped = dfS1_dropped.reset_index() 
print(len(dfS1_dropped))
dfS1_dropped.head(50)
# Out:
# 149604
# 56197
#     level_0  index               barcode   0_1   0_2     1     2     3     4  \
# 0         1     35  CCTAAGCGCTTACCCCAACC    42   116    72    72    21    14
# 1         2     36  TCGGACCCAGCTTGGAATAA    48   107    75    68    60    41
# 2         6     44  ATTCCTGTTACTAGATCAAA    34    97     4    57    34    21
# 3         7     46  CCCCCCAGGCTCGTGACGCC    65    61    39    37    51    18
# 4         8     48  AGTGATTGCGTATATCTGTT    46    38    24    25    46     9
# 5         9     49  GCCACAGCACCGGTCACACT    42    53    21    31    52    59
# 6        14     55  TTACCGACTACTCACATTGA    43    53    35    44    39    51
# 7        15     56  CGAACCCTCCGACGCGCTTT     7    46    31    66    23     8
# 8        16     57  CCCGACATCGCACGCAACGC    79    57    31    72    78    57
# 9        20     61  CCCTCACCCTATTATCTGCC    36    39    29    38    20    34
# 10       21     64  GCTCGTCATTAAGATTTACT  1039  1183  1073  1455  1971  2272
# 11       27     70  GCCTTCCCCCCACGTCTGCA    34    44    28    65    18    39
# 12       34     78  CGTCCTGTCTCCAAACGAAA    47    39    58    55    52    23
# 13       37     84  CACACTCAGAAAATCTGTTT    46    60    15    42    28     0
# 14       40     94  CCACCAGTACCGATATCAGG    44    39    30    44    64     0
# 15       41     95  CTCCCGCTCCGACACCTAAC    17    59    14    27    52    19
# 16       45     99  CCGGCTCTATTCTCCCACGC    74    79    48    37    52    41
# 17       49    105  CAACGGAAGCAGCGGGCCGG    43    21    37    45    36    24
# 18       52    110  ATGGATAACATAAGCTAACA    22    71    40    11    32    30
# 19       53    111  CCCTCCCGGACTCTCCGACA    72    30    59    93   146   103
# 20       56    116  CTTTCCCCCAGACTCATCGA    33    60     5    37    38    20
# 21       61    121  GAATTCCGCCACAATGCGGC    82    33     7    63    22    20
# 22       63    124  CGCCTCATCGTCGATCCCCT   104   223    45    51    11    21
# 23       66    127  ACCCTCAGTCCGTCCGGTAT    56    98    65   104    43    48
# 24       68    135  GCGGCGTCCCCCTGCCGCTC   185   187    95   131    72    54
# 25       78    151  GAATAACATCGATTCTACAC    67    65    81   110    63    45
# 26       89    169  CCGGGGCCCAGGCCCCCCTC    19    54     2    57    34    22
# 27       91    172  CCAGGCAGCGACTGACCGCC    22    54    77    74    70    20
# 28       98    182  ACACTCGGCCCCGACGACGT    29    78    19    38    12     9
# 29      100    185  ATTCCAAGCTTCTCCACATA    17    45    35    49    19    37
# 30      103    188  ACCAAATGCCTCAGCTGCAT    59    76    39    39    31    10
# 31      107    194  TATAGCCTGGCATGACCGTA    15    17    30    15    83    45
# 32      109    196  ACGTGGTGAAGCATGAAAGG    43    18    40    43    18    49
# 33      112    203  CCCCTGCTATCAGCAATTTC    41    70    32    49    46    48
# 34      114    205  CCGCCCGACCCAAAACCCAC    59    45    73    48    75    38
# 35      117    209  GTCGCGATACTTACCCGCAT    53    89    33    37    19    29
# 36      122    214  CCCTACCAGGCCACACCCCT   138   130    78   104    92   105
# 37      123    215  TCTGCCCTAGTGCGACCTTA    29    45    26    21    51    75
# 38      124    216  CGCTAGGCTGTGAGTCCGTA    42    37    50    87    74    55
# 39      125    218  CCCTGTACGGCTTGTTCCAC    66    37    26    84    45    68
# 40      130    225  GCCCATTCCCCATCACCTCG    64    66    76    41    81    64
# 41      131    226  CTCCCCCCCGGTCCCGCCCT    32    80    24    43    65    57
# 42      159    267  AAAGCCCCGCTCCCTCGCCG    43    51    18    26    38    13
# 43      163    271  GAACGCCCGGATCACCCACC    27    37    85    49    10    19
# 44      165    274  ACGCACTCGCACCAGAAGGC    58    49    51    23    34    19
# 45      172    283  TACTACTCGGACCAAGTAGC   101    74    36    10     8     0
# 46      175    288  CGCTACAACAACACCGCCAA    75    24    76    83    53    52
# 47      180    294  TCTATGATGTTGCGTGGAGC   113    80    84   117    61   144
# 48      183    297  CCGCCAGTTGTGGGGGTCGG   228   225   260   257   202   216
# 49      198    318  CGTTCAAACTCTCTTCATCG    71    47    49    57    48    35
#
#    strand        pos    gene_ID type gene_symbol  \
# 0       +  2881032.0  ECB_02693  cds        yqeG
# 1       +  4065973.0  ECB_03781  cds        yiiG
# 2       +  1468609.0  ECB_01382  cds         NaN
# 3       -  2392940.0  ECB_02257  cds        yfcO
# 4       +  2205123.0  ECB_02090  cds        yeiJ
# 5       -  4437424.0  ECB_04099  cds        yjfF
# 6       -  3789895.0  ECB_03531  cds         NaN
# 7       -  3119814.0  ECB_02915  cds        ygiL
# 8       +  3584927.0  ECB_03356  cds        yhiD
# 9       -  2364812.0  ECB_02227  cds        yfcG
# 10      -  3825996.0  ECB_03568  cds        yidE
# 11      -  2352777.0  ECB_02216  cds        yfbR
# 12      +  3198194.0  ECB_02984  cds        tdcB
# 13      +  2791651.0  ECB_02620  cds        ygcE
# 14      -   157515.0  ECB_00138  cds        htrE
# 15      +  3861756.0  ECB_03604  cds        yieC
# 16      +  3124250.0  ECB_02918  cds        yqiI
# 17      +  4230277.0  ECB_03910  cds        yjbI
# 18      +  3820394.0  ECB_03564  cds        yidL
# 19      +  3738702.0  ECB_03480  cds        waaV
# 20      -  2137401.0  ECB_02030  cds        yegX
# 21      +   482314.0  ECB_00435  cds        copA
# 22      +   571527.0  ECB_00529  cds         NaN
# 23      +   892072.0  ECB_00832  cds         NaN
# 24      -   291093.0  ECB_00259  cds        ykgI
# 25      +   782643.0  ECB_00723  cds        ybhI
# 26      +  3967938.0  ECB_03698  cds        rarD
# 27      -  2118115.0  ECB_02004  cds         NaN
# 28      -  4390294.0  ECB_04051  cds        yjfL
# 29      +  3861130.0  ECB_03604  cds        yieC
# 30      -  2128076.0  ECB_02020  cds        gatA
# 31      +  1017699.0  ECB_00944  cds        ycbS
# 32      +  1887552.0  ECB_01797  cds         NaN
# 33      +   826075.0  ECB_00766  cds        dinG
# 34      +   797173.0  ECB_00738  cds         NaN
# 35      +   697884.0  ECB_00646  cds        ybfP
# 36      +  3793772.0  ECB_03536  cds        insI
# 37      -  1617822.0  ECB_01528  cds         NaN
# 38      +  3028121.0  ECB_02828  cds         NaN
# 39      -  2316059.0  ECB_02181  cds        yfbG
# 40      -  3866784.0  ECB_03607  cds        bglG
# 41      -   154561.0  ECB_00136  cds        yadL
# 42      +  4305975.0  ECB_03980  cds        yjdA
# 43      +  4527702.0  ECB_04186  cds        fimD
# 44      +  4041604.0  ECB_03759  cds        yihN
# 45      -  2006185.0  ECB_01904  cds        insD
# 46      +  4071810.0  ECB_03786  cds         NaN
# 47      -  3729902.0  ECB_03473  cds        yibD
# 48      -  3684109.0  ECB_03438  cds         NaN
# 49      -  2662350.0  ECB_02490  cds        aroF
#
#                                           description
# 0                               predicted transporter
# 1                                hypothetical protein
# 2                                hypothetical protein
# 3                                hypothetical protein
# 4                    predicted nucleoside transporter
# 5                 predicted sugar transporter subunit
# 6                                hypothetical protein
# 7             predicted fimbrial-like adhesin protein
# 8   predicted Mg(2+) transport ATPase inner membra...
# 9                 predicted glutathione S-transferase
# 10                               hypothetical protein
# 11                               hypothetical protein
# 12                              threonine dehydratase
# 13                                   predicted kinase
# 14             predicted outer membrane usher protein
# 15  carbohydrate-specific outer membrane porin, cr...
# 16                               hypothetical protein
# 17                               hypothetical protein
# 18    predicted DNA-binding transcriptional regulator
# 19               putative beta1,3-glucosyltransferase
# 20                                predicted hydrolase
# 21                                 copper transporter
# 22                               hypothetical protein
# 23                     probable capsid portal protein
# 24                               hypothetical protein
# 25                              predicted transporter
# 26      predicted chloramphenical resistance permease
# 27                         Replication gene A protein
# 28                   conserved inner membrane protein
# 29  carbohydrate-specific outer membrane porin, cr...
# 30    galactitol-specific enzyme IIA component of PTS
# 31             predicted outer membrane usher protein
# 32                               hypothetical protein
# 33                         ATP-dependent DNA helicase
# 34                               hypothetical protein
# 35                               hypothetical protein
# 36                                   IS30 transposase
# 37             antitermination protein Q-like protein
# 38             Polysialic acid transport protein kpsM
# 39                               hypothetical protein
# 40   transcriptional antiterminator of the bgl operon
# 41            predicted fimbrial-like adhesin protein
# 42  conserved hypothetical protein with nucleoside...
# 43  outer membrane usher protein, type 1 fimbrial ...
# 44                              predicted transporter
# 45           IS2 insertion element transposase InsAB'
# 46                                putative glycoporin
# 47                     predicted glycosyl transferase
# 48                     conserved hypothetical protein
# 49  3-deoxy-D-arabino-heptulosonate-7-phosphate sy...

# %%
#dictionary with days and corresponding Rtot
RtotS1_dict = dict(zip(r_totS1.columns.values, r_totS1.iloc[0].values))

dfS1_freqs = dfS1_dropped.copy() #df with freqs of all days

def frequency(df_freqs, rtot):
    for day in ["0_1","0_2","1","2","3","4"]:
        freq_vals = [] #all frequency values
        for count in df_freqs[day]:
            freq = count/rtot[day]
            freq_vals.append(freq)
        df_freqs["%s_freq" % day] = freq_vals
    df_freqs.insert(15, "0_freq", df_freqs[["0_1_freq", "0_2_freq"]].mean(axis=1))
    
frequency(dfS1_freqs, RtotS1_dict)
dfS1_freqs.head(50)
# Out:
#     level_0  index               barcode   0_1   0_2     1     2     3     4  \
# 0         1     35  CCTAAGCGCTTACCCCAACC    42   116    72    72    21    14
# 1         2     36  TCGGACCCAGCTTGGAATAA    48   107    75    68    60    41
# 2         6     44  ATTCCTGTTACTAGATCAAA    34    97     4    57    34    21
# 3         7     46  CCCCCCAGGCTCGTGACGCC    65    61    39    37    51    18
# 4         8     48  AGTGATTGCGTATATCTGTT    46    38    24    25    46     9
# 5         9     49  GCCACAGCACCGGTCACACT    42    53    21    31    52    59
# 6        14     55  TTACCGACTACTCACATTGA    43    53    35    44    39    51
# 7        15     56  CGAACCCTCCGACGCGCTTT     7    46    31    66    23     8
# 8        16     57  CCCGACATCGCACGCAACGC    79    57    31    72    78    57
# 9        20     61  CCCTCACCCTATTATCTGCC    36    39    29    38    20    34
# 10       21     64  GCTCGTCATTAAGATTTACT  1039  1183  1073  1455  1971  2272
# 11       27     70  GCCTTCCCCCCACGTCTGCA    34    44    28    65    18    39
# 12       34     78  CGTCCTGTCTCCAAACGAAA    47    39    58    55    52    23
# 13       37     84  CACACTCAGAAAATCTGTTT    46    60    15    42    28     0
# 14       40     94  CCACCAGTACCGATATCAGG    44    39    30    44    64     0
# 15       41     95  CTCCCGCTCCGACACCTAAC    17    59    14    27    52    19
# 16       45     99  CCGGCTCTATTCTCCCACGC    74    79    48    37    52    41
# 17       49    105  CAACGGAAGCAGCGGGCCGG    43    21    37    45    36    24
# 18       52    110  ATGGATAACATAAGCTAACA    22    71    40    11    32    30
# 19       53    111  CCCTCCCGGACTCTCCGACA    72    30    59    93   146   103
# 20       56    116  CTTTCCCCCAGACTCATCGA    33    60     5    37    38    20
# 21       61    121  GAATTCCGCCACAATGCGGC    82    33     7    63    22    20
# 22       63    124  CGCCTCATCGTCGATCCCCT   104   223    45    51    11    21
# 23       66    127  ACCCTCAGTCCGTCCGGTAT    56    98    65   104    43    48
# 24       68    135  GCGGCGTCCCCCTGCCGCTC   185   187    95   131    72    54
# 25       78    151  GAATAACATCGATTCTACAC    67    65    81   110    63    45
# 26       89    169  CCGGGGCCCAGGCCCCCCTC    19    54     2    57    34    22
# 27       91    172  CCAGGCAGCGACTGACCGCC    22    54    77    74    70    20
# 28       98    182  ACACTCGGCCCCGACGACGT    29    78    19    38    12     9
# 29      100    185  ATTCCAAGCTTCTCCACATA    17    45    35    49    19    37
# 30      103    188  ACCAAATGCCTCAGCTGCAT    59    76    39    39    31    10
# 31      107    194  TATAGCCTGGCATGACCGTA    15    17    30    15    83    45
# 32      109    196  ACGTGGTGAAGCATGAAAGG    43    18    40    43    18    49
# 33      112    203  CCCCTGCTATCAGCAATTTC    41    70    32    49    46    48
# 34      114    205  CCGCCCGACCCAAAACCCAC    59    45    73    48    75    38
# 35      117    209  GTCGCGATACTTACCCGCAT    53    89    33    37    19    29
# 36      122    214  CCCTACCAGGCCACACCCCT   138   130    78   104    92   105
# 37      123    215  TCTGCCCTAGTGCGACCTTA    29    45    26    21    51    75
# 38      124    216  CGCTAGGCTGTGAGTCCGTA    42    37    50    87    74    55
# 39      125    218  CCCTGTACGGCTTGTTCCAC    66    37    26    84    45    68
# 40      130    225  GCCCATTCCCCATCACCTCG    64    66    76    41    81    64
# 41      131    226  CTCCCCCCCGGTCCCGCCCT    32    80    24    43    65    57
# 42      159    267  AAAGCCCCGCTCCCTCGCCG    43    51    18    26    38    13
# 43      163    271  GAACGCCCGGATCACCCACC    27    37    85    49    10    19
# 44      165    274  ACGCACTCGCACCAGAAGGC    58    49    51    23    34    19
# 45      172    283  TACTACTCGGACCAAGTAGC   101    74    36    10     8     0
# 46      175    288  CGCTACAACAACACCGCCAA    75    24    76    83    53    52
# 47      180    294  TCTATGATGTTGCGTGGAGC   113    80    84   117    61   144
# 48      183    297  CCGCCAGTTGTGGGGGTCGG   228   225   260   257   202   216
# 49      198    318  CGTTCAAACTCTCTTCATCG    71    47    49    57    48    35
#
#    strand  ...  type gene_symbol  \
# 0       +  ...   cds        yqeG
# 1       +  ...   cds        yiiG
# 2       +  ...   cds         NaN
# 3       -  ...   cds        yfcO
# 4       +  ...   cds        yeiJ
# 5       -  ...   cds        yjfF
# 6       -  ...   cds         NaN
# 7       -  ...   cds        ygiL
# 8       +  ...   cds        yhiD
# 9       -  ...   cds        yfcG
# 10      -  ...   cds        yidE
# 11      -  ...   cds        yfbR
# 12      +  ...   cds        tdcB
# 13      +  ...   cds        ygcE
# 14      -  ...   cds        htrE
# 15      +  ...   cds        yieC
# 16      +  ...   cds        yqiI
# 17      +  ...   cds        yjbI
# 18      +  ...   cds        yidL
# 19      +  ...   cds        waaV
# 20      -  ...   cds        yegX
# 21      +  ...   cds        copA
# 22      +  ...   cds         NaN
# 23      +  ...   cds         NaN
# 24      -  ...   cds        ykgI
# 25      +  ...   cds        ybhI
# 26      +  ...   cds        rarD
# 27      -  ...   cds         NaN
# 28      -  ...   cds        yjfL
# 29      +  ...   cds        yieC
# 30      -  ...   cds        gatA
# 31      +  ...   cds        ycbS
# 32      +  ...   cds         NaN
# 33      +  ...   cds        dinG
# 34      +  ...   cds         NaN
# 35      +  ...   cds        ybfP
# 36      +  ...   cds        insI
# 37      -  ...   cds         NaN
# 38      +  ...   cds         NaN
# 39      -  ...   cds        yfbG
# 40      -  ...   cds        bglG
# 41      -  ...   cds        yadL
# 42      +  ...   cds        yjdA
# 43      +  ...   cds        fimD
# 44      +  ...   cds        yihN
# 45      -  ...   cds        insD
# 46      +  ...   cds         NaN
# 47      -  ...   cds        yibD
# 48      -  ...   cds         NaN
# 49      -  ...   cds        aroF
#
#                                           description    0_freq      0_1_freq  \
# 0                               predicted transporter  0.000008  4.366829e-06
# 1                                hypothetical protein  0.000007  4.990662e-06
# 2                                hypothetical protein  0.000006  3.535052e-06
# 3                                hypothetical protein  0.000006  6.758188e-06
# 4                    predicted nucleoside transporter  0.000004  4.782718e-06
# 5                 predicted sugar transporter subunit  0.000005  4.366829e-06
# 6                                hypothetical protein  0.000005  4.470801e-06
# 7             predicted fimbrial-like adhesin protein  0.000002  7.278048e-07
# 8   predicted Mg(2+) transport ATPase inner membra...  0.000007  8.213797e-06
# 9                 predicted glutathione S-transferase  0.000004  3.742996e-06
# 10                               hypothetical protein  0.000109  1.080270e-04
# 11                               hypothetical protein  0.000004  3.535052e-06
# 12                              threonine dehydratase  0.000004  4.886690e-06
# 13                                   predicted kinase  0.000005  4.782718e-06
# 14             predicted outer membrane usher protein  0.000004  4.574773e-06
# 15  carbohydrate-specific outer membrane porin, cr...  0.000004  1.767526e-06
# 16                               hypothetical protein  0.000007  7.693937e-06
# 17                               hypothetical protein  0.000003  4.470801e-06
# 18    predicted DNA-binding transcriptional regulator  0.000004  2.287387e-06
# 19               putative beta1,3-glucosyltransferase  0.000005  7.485993e-06
# 20                                predicted hydrolase  0.000004  3.431080e-06
# 21                                 copper transporter  0.000006  8.525714e-06
# 22                               hypothetical protein  0.000016  1.081310e-05
# 23                     probable capsid portal protein  0.000007  5.822439e-06
# 24                               hypothetical protein  0.000018  1.923484e-05
# 25                              predicted transporter  0.000006  6.966132e-06
# 26      predicted chloramphenical resistance permease  0.000003  1.975470e-06
# 27                         Replication gene A protein  0.000004  2.287387e-06
# 28                   conserved inner membrane protein  0.000005  3.015191e-06
# 29  carbohydrate-specific outer membrane porin, cr...  0.000003  1.767526e-06
# 30    galactitol-specific enzyme IIA component of PTS  0.000007  6.134355e-06
# 31             predicted outer membrane usher protein  0.000002  1.559582e-06
# 32                               hypothetical protein  0.000003  4.470801e-06
# 33                         ATP-dependent DNA helicase  0.000005  4.262857e-06
# 34                               hypothetical protein  0.000005  6.134355e-06
# 35                               hypothetical protein  0.000007  5.510522e-06
# 36                                   IS30 transposase  0.000013  1.434815e-05
# 37             antitermination protein Q-like protein  0.000004  3.015191e-06
# 38             Polysialic acid transport protein kpsM  0.000004  4.366829e-06
# 39                               hypothetical protein  0.000005  6.862160e-06
# 40   transcriptional antiterminator of the bgl operon  0.000006  6.654216e-06
# 41            predicted fimbrial-like adhesin protein  0.000005  3.327108e-06
# 42  conserved hypothetical protein with nucleoside...  0.000005  4.470801e-06
# 43  outer membrane usher protein, type 1 fimbrial ...  0.000003  2.807247e-06
# 44                              predicted transporter  0.000005  6.030383e-06
# 45           IS2 insertion element transposase InsAB'  0.000009  1.050118e-05
# 46                                putative glycoporin  0.000005  7.797909e-06
# 47                     predicted glycosyl transferase  0.000010  1.174885e-05
# 48                     conserved hypothetical protein  0.000022  2.370564e-05
# 49  3-deoxy-D-arabino-heptulosonate-7-phosphate sy...  0.000006  7.382020e-06
#
#     0_2_freq        1_freq    2_freq        3_freq    4_freq
# 0   0.000011  8.171155e-06  0.000007  2.433273e-06  0.000002
# 1   0.000010  8.511620e-06  0.000007  6.952209e-06  0.000005
# 2   0.000009  4.539530e-07  0.000006  3.939585e-06  0.000003
# 3   0.000006  4.426042e-06  0.000004  5.909377e-06  0.000002
# 4   0.000004  2.723718e-06  0.000003  5.330027e-06  0.000001
# 5   0.000005  2.383253e-06  0.000003  6.025247e-06  0.000008
# 6   0.000005  3.972089e-06  0.000005  4.518936e-06  0.000007
# 7   0.000004  3.518136e-06  0.000007  2.665013e-06  0.000001
# 8   0.000005  3.518136e-06  0.000007  9.037871e-06  0.000007
# 9   0.000004  3.291160e-06  0.000004  2.317403e-06  0.000004
# 10  0.000109  1.217729e-04  0.000149  2.283801e-04  0.000296
# 11  0.000004  3.177671e-06  0.000007  2.085663e-06  0.000005
# 12  0.000004  6.582319e-06  0.000006  6.025247e-06  0.000003
# 13  0.000006  1.702324e-06  0.000004  3.244364e-06  0.000000
# 14  0.000004  3.404648e-06  0.000005  7.415689e-06  0.000000
# 15  0.000005  1.588836e-06  0.000003  6.025247e-06  0.000002
# 16  0.000007  5.447437e-06  0.000004  6.025247e-06  0.000005
# 17  0.000002  4.199066e-06  0.000005  4.171325e-06  0.000003
# 18  0.000007  4.539530e-06  0.000001  3.707845e-06  0.000004
# 19  0.000003  6.695807e-06  0.000010  1.691704e-05  0.000013
# 20  0.000006  5.674413e-07  0.000004  4.403065e-06  0.000003
# 21  0.000003  7.944178e-07  0.000006  2.549143e-06  0.000003
# 22  0.000021  5.106972e-06  0.000005  1.274572e-06  0.000003
# 23  0.000009  7.376737e-06  0.000011  4.982416e-06  0.000006
# 24  0.000017  1.078138e-05  0.000013  8.342650e-06  0.000007
# 25  0.000006  9.192549e-06  0.000011  7.299819e-06  0.000006
# 26  0.000005  2.269765e-07  0.000006  3.939585e-06  0.000003
# 27  0.000005  8.738596e-06  0.000008  8.110910e-06  0.000003
# 28  0.000007  2.156277e-06  0.000004  1.390442e-06  0.000001
# 29  0.000004  3.972089e-06  0.000005  2.201533e-06  0.000005
# 30  0.000007  4.426042e-06  0.000004  3.591974e-06  0.000001
# 31  0.000002  3.404648e-06  0.000002  9.617222e-06  0.000006
# 32  0.000002  4.539530e-06  0.000004  2.085663e-06  0.000006
# 33  0.000006  3.631624e-06  0.000005  5.330027e-06  0.000006
# 34  0.000004  8.284643e-06  0.000005  8.690261e-06  0.000005
# 35  0.000008  3.745113e-06  0.000004  2.201533e-06  0.000004
# 36  0.000012  8.852084e-06  0.000011  1.066005e-05  0.000014
# 37  0.000004  2.950695e-06  0.000002  5.909377e-06  0.000010
# 38  0.000003  5.674413e-06  0.000009  8.574391e-06  0.000007
# 39  0.000003  2.950695e-06  0.000009  5.214156e-06  0.000009
# 40  0.000006  8.625108e-06  0.000004  9.385482e-06  0.000008
# 41  0.000007  2.723718e-06  0.000004  7.531559e-06  0.000007
# 42  0.000005  2.042789e-06  0.000003  4.403065e-06  0.000002
# 43  0.000003  9.646502e-06  0.000005  1.158701e-06  0.000002
# 44  0.000005  5.787901e-06  0.000002  3.939585e-06  0.000002
# 45  0.000007  4.085577e-06  0.000001  9.269611e-07  0.000000
# 46  0.000002  8.625108e-06  0.000009  6.141118e-06  0.000007
# 47  0.000007  9.533014e-06  0.000012  7.068079e-06  0.000019
# 48  0.000021  2.950695e-05  0.000026  2.340577e-05  0.000028
# 49  0.000004  5.560925e-06  0.000006  5.561767e-06  0.000005
#
# [50 rows x 22 columns]

# %%
dfS1_x = dfS1_freqs.copy() #df with freqs of VST (variance stabilizing transformation)

def x_freq(df_x):
    for freq in ["0_freq","1_freq","2_freq","3_freq","4_freq"]:
        x_vals = [] #all frequency values
        for count in df_x[freq]:
            count = np.sqrt(count)
            x_vals.append(count)
        df_x["x(%s)" % freq] = x_vals

df_S1 = x_freq(dfS1_x)  
dfS1_x = dfS1_x.drop(dfS1_x.columns[[0, 1, 3, 4, 5, 6, 7, 8, 15, 16, 17, 18, 19, 20, 21]], axis=1)
dfS1_x.head(50)
# Out:
#                  barcode strand        pos    gene_ID type gene_symbol  \
# 0   CCTAAGCGCTTACCCCAACC      +  2881032.0  ECB_02693  cds        yqeG
# 1   TCGGACCCAGCTTGGAATAA      +  4065973.0  ECB_03781  cds        yiiG
# 2   ATTCCTGTTACTAGATCAAA      +  1468609.0  ECB_01382  cds         NaN
# 3   CCCCCCAGGCTCGTGACGCC      -  2392940.0  ECB_02257  cds        yfcO
# 4   AGTGATTGCGTATATCTGTT      +  2205123.0  ECB_02090  cds        yeiJ
# 5   GCCACAGCACCGGTCACACT      -  4437424.0  ECB_04099  cds        yjfF
# 6   TTACCGACTACTCACATTGA      -  3789895.0  ECB_03531  cds         NaN
# 7   CGAACCCTCCGACGCGCTTT      -  3119814.0  ECB_02915  cds        ygiL
# 8   CCCGACATCGCACGCAACGC      +  3584927.0  ECB_03356  cds        yhiD
# 9   CCCTCACCCTATTATCTGCC      -  2364812.0  ECB_02227  cds        yfcG
# 10  GCTCGTCATTAAGATTTACT      -  3825996.0  ECB_03568  cds        yidE
# 11  GCCTTCCCCCCACGTCTGCA      -  2352777.0  ECB_02216  cds        yfbR
# 12  CGTCCTGTCTCCAAACGAAA      +  3198194.0  ECB_02984  cds        tdcB
# 13  CACACTCAGAAAATCTGTTT      +  2791651.0  ECB_02620  cds        ygcE
# 14  CCACCAGTACCGATATCAGG      -   157515.0  ECB_00138  cds        htrE
# 15  CTCCCGCTCCGACACCTAAC      +  3861756.0  ECB_03604  cds        yieC
# 16  CCGGCTCTATTCTCCCACGC      +  3124250.0  ECB_02918  cds        yqiI
# 17  CAACGGAAGCAGCGGGCCGG      +  4230277.0  ECB_03910  cds        yjbI
# 18  ATGGATAACATAAGCTAACA      +  3820394.0  ECB_03564  cds        yidL
# 19  CCCTCCCGGACTCTCCGACA      +  3738702.0  ECB_03480  cds        waaV
# 20  CTTTCCCCCAGACTCATCGA      -  2137401.0  ECB_02030  cds        yegX
# 21  GAATTCCGCCACAATGCGGC      +   482314.0  ECB_00435  cds        copA
# 22  CGCCTCATCGTCGATCCCCT      +   571527.0  ECB_00529  cds         NaN
# 23  ACCCTCAGTCCGTCCGGTAT      +   892072.0  ECB_00832  cds         NaN
# 24  GCGGCGTCCCCCTGCCGCTC      -   291093.0  ECB_00259  cds        ykgI
# 25  GAATAACATCGATTCTACAC      +   782643.0  ECB_00723  cds        ybhI
# 26  CCGGGGCCCAGGCCCCCCTC      +  3967938.0  ECB_03698  cds        rarD
# 27  CCAGGCAGCGACTGACCGCC      -  2118115.0  ECB_02004  cds         NaN
# 28  ACACTCGGCCCCGACGACGT      -  4390294.0  ECB_04051  cds        yjfL
# 29  ATTCCAAGCTTCTCCACATA      +  3861130.0  ECB_03604  cds        yieC
# 30  ACCAAATGCCTCAGCTGCAT      -  2128076.0  ECB_02020  cds        gatA
# 31  TATAGCCTGGCATGACCGTA      +  1017699.0  ECB_00944  cds        ycbS
# 32  ACGTGGTGAAGCATGAAAGG      +  1887552.0  ECB_01797  cds         NaN
# 33  CCCCTGCTATCAGCAATTTC      +   826075.0  ECB_00766  cds        dinG
# 34  CCGCCCGACCCAAAACCCAC      +   797173.0  ECB_00738  cds         NaN
# 35  GTCGCGATACTTACCCGCAT      +   697884.0  ECB_00646  cds        ybfP
# 36  CCCTACCAGGCCACACCCCT      +  3793772.0  ECB_03536  cds        insI
# 37  TCTGCCCTAGTGCGACCTTA      -  1617822.0  ECB_01528  cds         NaN
# 38  CGCTAGGCTGTGAGTCCGTA      +  3028121.0  ECB_02828  cds         NaN
# 39  CCCTGTACGGCTTGTTCCAC      -  2316059.0  ECB_02181  cds        yfbG
# 40  GCCCATTCCCCATCACCTCG      -  3866784.0  ECB_03607  cds        bglG
# 41  CTCCCCCCCGGTCCCGCCCT      -   154561.0  ECB_00136  cds        yadL
# 42  AAAGCCCCGCTCCCTCGCCG      +  4305975.0  ECB_03980  cds        yjdA
# 43  GAACGCCCGGATCACCCACC      +  4527702.0  ECB_04186  cds        fimD
# 44  ACGCACTCGCACCAGAAGGC      +  4041604.0  ECB_03759  cds        yihN
# 45  TACTACTCGGACCAAGTAGC      -  2006185.0  ECB_01904  cds        insD
# 46  CGCTACAACAACACCGCCAA      +  4071810.0  ECB_03786  cds         NaN
# 47  TCTATGATGTTGCGTGGAGC      -  3729902.0  ECB_03473  cds        yibD
# 48  CCGCCAGTTGTGGGGGTCGG      -  3684109.0  ECB_03438  cds         NaN
# 49  CGTTCAAACTCTCTTCATCG      -  2662350.0  ECB_02490  cds        aroF
#
#                                           description  x(0_freq)  x(1_freq)  \
# 0                               predicted transporter   0.002744   0.002859
# 1                                hypothetical protein   0.002725   0.002917
# 2                                hypothetical protein   0.002498   0.000674
# 3                                hypothetical protein   0.002488   0.002104
# 4                    predicted nucleoside transporter   0.002035   0.001650
# 5                 predicted sugar transporter subunit   0.002151   0.001544
# 6                                hypothetical protein   0.002163   0.001993
# 7             predicted fimbrial-like adhesin protein   0.001576   0.001876
# 8   predicted Mg(2+) transport ATPase inner membra...   0.002595   0.001876
# 9                 predicted glutathione S-transferase   0.001915   0.001814
# 10                               hypothetical protein   0.010418   0.011035
# 11                               hypothetical protein   0.001948   0.001783
# 12                              threonine dehydratase   0.002059   0.002566
# 13                                   predicted kinase   0.002271   0.001305
# 14             predicted outer membrane usher protein   0.002021   0.001845
# 15  carbohydrate-specific outer membrane porin, cr...   0.001898   0.001260
# 16                               hypothetical protein   0.002736   0.002334
# 17                               hypothetical protein   0.001790   0.002049
# 18    predicted DNA-binding transcriptional regulator   0.002101   0.002131
# 19               putative beta1,3-glucosyltransferase   0.002264   0.002588
# 20                                predicted hydrolase   0.002117   0.000753
# 21                                 copper transporter   0.002405   0.000891
# 22                               hypothetical protein   0.003960   0.002260
# 23                     probable capsid portal protein   0.002725   0.002716
# 24                               hypothetical protein   0.004270   0.003284
# 25                              predicted transporter   0.002545   0.003032
# 26      predicted chloramphenical resistance permease   0.001865   0.000476
# 27                         Replication gene A protein   0.001906   0.002956
# 28                   conserved inner membrane protein   0.002259   0.001468
# 29  carbohydrate-specific outer membrane porin, cr...   0.001720   0.001993
# 30    galactitol-specific enzyme IIA component of PTS   0.002563   0.002104
# 31             predicted outer membrane usher protein   0.001250   0.001845
# 32                               hypothetical protein   0.001751   0.002131
# 33                         ATP-dependent DNA helicase   0.002315   0.001906
# 34                               hypothetical protein   0.002267   0.002878
# 35                               hypothetical protein   0.002619   0.001935
# 36                                   IS30 transposase   0.003628   0.002975
# 37             antitermination protein Q-like protein   0.001892   0.001718
# 38             Polysialic acid transport protein kpsM   0.001972   0.002382
# 39                               hypothetical protein   0.002266   0.001718
# 40   transcriptional antiterminator of the bgl operon   0.002524   0.002937
# 41            predicted fimbrial-like adhesin protein   0.002313   0.001650
# 42  conserved hypothetical protein with nucleoside...   0.002141   0.001429
# 43  outer membrane usher protein, type 1 fimbrial ...   0.001763   0.003106
# 44                              predicted transporter   0.002296   0.002406
# 45           IS2 insertion element transposase InsAB'   0.002943   0.002021
# 46                                putative glycoporin   0.002237   0.002937
# 47                     predicted glycosyl transferase   0.003092   0.003088
# 48                     conserved hypothetical protein   0.004714   0.005432
# 49  3-deoxy-D-arabino-heptulosonate-7-phosphate sy...   0.002420   0.002358
#
#     x(2_freq)  x(3_freq)  x(4_freq)
# 0    0.002719   0.001560   0.001350
# 1    0.002643   0.002637   0.002310
# 2    0.002420   0.001985   0.001654
# 3    0.001949   0.002431   0.001531
# 4    0.001602   0.002309   0.001082
# 5    0.001784   0.002455   0.002772
# 6    0.002126   0.002126   0.002577
# 7    0.002604   0.001632   0.001021
# 8    0.002719   0.003006   0.002724
# 9    0.001976   0.001522   0.002104
# 10   0.012224   0.015112   0.017199
# 11   0.002584   0.001444   0.002253
# 12   0.002377   0.002455   0.001730
# 13   0.002077   0.001801   0.000000
# 14   0.002126   0.002723   0.000000
# 15   0.001665   0.002455   0.001573
# 16   0.001949   0.002455   0.002310
# 17   0.002150   0.002042   0.001768
# 18   0.001063   0.001926   0.001976
# 19   0.003091   0.004113   0.003662
# 20   0.001949   0.002098   0.001614
# 21   0.002544   0.001597   0.001614
# 22   0.002289   0.001129   0.001654
# 23   0.003268   0.002232   0.002500
# 24   0.003668   0.002888   0.002652
# 25   0.003361   0.002702   0.002420
# 26   0.002420   0.001985   0.001692
# 27   0.002757   0.002848   0.001614
# 28   0.001976   0.001179   0.001082
# 29   0.002243   0.001484   0.002195
# 30   0.002001   0.001895   0.001141
# 31   0.001241   0.003101   0.002420
# 32   0.002101   0.001444   0.002526
# 33   0.002243   0.002309   0.002500
# 34   0.002220   0.002948   0.002224
# 35   0.001949   0.001484   0.001943
# 36   0.003268   0.003265   0.003697
# 37   0.001469   0.002431   0.003125
# 38   0.002989   0.002928   0.002676
# 39   0.002937   0.002283   0.002975
# 40   0.002052   0.003064   0.002887
# 41   0.002101   0.002744   0.002724
# 42   0.001634   0.002098   0.001301
# 43   0.002243   0.001076   0.001573
# 44   0.001537   0.001985   0.001573
# 45   0.001013   0.000963   0.000000
# 46   0.002920   0.002478   0.002602
# 47   0.003466   0.002659   0.004330
# 48   0.005138   0.004838   0.005303
# 49   0.002420   0.002358   0.002135

# %%
dfS1_x_corr = dfS1_x.copy() #df with corrected freqs of VST (variance stabilizing transformation)
df_s = pd.read_csv('https://media.githubusercontent.com/media/joaoascensao/S-L-REL606-BarSeq/master/E_F/data/fitness/FS1_fitness.csv')
df_t_xbar = pd.read_csv('https://media.githubusercontent.com/media/joaoascensao/S-L-REL606-BarSeq/master/E_F/data/meanfitness/FS1_xbar.csv')

df_t_xbar.head()
# Out:
#    Unnamed: 0  Day label      xbar    stderr       gens
# 0           0          1  0.010207  0.000375   6.643856
# 1           1          2  0.005280  0.000195  13.287712
# 2           2          3  0.003811  0.000151  19.931569
# 3           3          4  0.003251  0.000140  26.575425

# %%
tS1_dict = dict(zip(df_t_xbar["Day label"], df_t_xbar["gens"]))
xbarS1_dict = dict(zip(df_t_xbar["Day label"], df_t_xbar["xbar"]))
sS1_dict = dict(zip(df_s["gene_ID"], df_s["s"]))

print(tS1_dict)
print(xbarS1_dict)
# Out:
# {1: 6.64385619, 2: 13.28771238, 3: 19.93156857, 4: 26.57542476}
# {1: 0.010207445152528943, 2: 0.005279710051303896, 3: 0.003810948070721187, 4: 0.003250505626719311}

# %%
dfS1_x_corr = dfS1_x.copy()

#dropping rows/gene_IDs with no "s" value
no_s = []
for i in range(len(dfS1_x_corr)):
    index_gene = dfS1_x_corr.columns.get_loc("gene_ID")
    if dfS1_x_corr.iloc[i,index_gene] not in sS1_dict.keys():
        no_s.append(i)
dfS1_x_corr.drop(no_s, axis=0, inplace=True)
dfS1_x_corr = dfS1_x_corr.reset_index()
dfS1_x_corr = dfS1_x_corr.drop(dfS1_x_corr.columns[[0]], axis=1)

#calculating x_corrected
days = [1, 2, 3, 4]
x_freqs = ["x(1_freq)","x(2_freq)","x(3_freq)","x(4_freq)"]

def x_corr_form(day, x, s_dict, t_dict, xbar_dict, df_x_corr):
    x_corr_vals = []
    for i in range(len(df_x_corr)):
        #index = day-1
        index_0 = df_x_corr.columns.get_loc("x(0_freq)")
        index_t = df_x_corr.columns.get_loc(x)
        x_0 = df_x_corr.iloc[i, index_0]
        x_t = df_x_corr.iloc[i, index_t]
        index_gene = df_x_corr.columns.get_loc("gene_ID")
        gene_ID = df_x_corr.iloc[i, index_gene]
        if gene_ID in s_dict.keys():
            s = s_dict[gene_ID]
        else:
            continue;
        t = t_dict[day]
        xbar = xbar_dict[day]
        x_corr = x_corr_ele(x_0, x_t, s, xbar, t)
        x_corr_vals.append(x_corr)
    return x_corr_vals
        
def x_corr_ele(x_0, x_t, s, xbar, t):
    x_corr = x_t - (x_0*math.exp((s-xbar)* (t/2)))
    return x_corr

#x_corr
for day, x in zip(days, x_freqs):
    x_corr = x_corr_form(day, x, sS1_dict, tS1_dict, xbarS1_dict, dfS1_x_corr)
    dfS1_x_corr["x_corr(%s)" % day] = x_corr
    
print(len(dfS1_x_corr))
dfS1_x_corr.head(50)
# Out:
# 48561
#                  barcode strand        pos    gene_ID type gene_symbol  \
# 0   CCTAAGCGCTTACCCCAACC      +  2881032.0  ECB_02693  cds        yqeG
# 1   TCGGACCCAGCTTGGAATAA      +  4065973.0  ECB_03781  cds        yiiG
# 2   CCCCCCAGGCTCGTGACGCC      -  2392940.0  ECB_02257  cds        yfcO
# 3   AGTGATTGCGTATATCTGTT      +  2205123.0  ECB_02090  cds        yeiJ
# 4   GCCACAGCACCGGTCACACT      -  4437424.0  ECB_04099  cds        yjfF
# 5   CGAACCCTCCGACGCGCTTT      -  3119814.0  ECB_02915  cds        ygiL
# 6   CCCGACATCGCACGCAACGC      +  3584927.0  ECB_03356  cds        yhiD
# 7   CCCTCACCCTATTATCTGCC      -  2364812.0  ECB_02227  cds        yfcG
# 8   GCTCGTCATTAAGATTTACT      -  3825996.0  ECB_03568  cds        yidE
# 9   GCCTTCCCCCCACGTCTGCA      -  2352777.0  ECB_02216  cds        yfbR
# 10  CGTCCTGTCTCCAAACGAAA      +  3198194.0  ECB_02984  cds        tdcB
# 11  CACACTCAGAAAATCTGTTT      +  2791651.0  ECB_02620  cds        ygcE
# 12  CCACCAGTACCGATATCAGG      -   157515.0  ECB_00138  cds        htrE
# 13  CTCCCGCTCCGACACCTAAC      +  3861756.0  ECB_03604  cds        yieC
# 14  CCGGCTCTATTCTCCCACGC      +  3124250.0  ECB_02918  cds        yqiI
# 15  CAACGGAAGCAGCGGGCCGG      +  4230277.0  ECB_03910  cds        yjbI
# 16  ATGGATAACATAAGCTAACA      +  3820394.0  ECB_03564  cds        yidL
# 17  CCCTCCCGGACTCTCCGACA      +  3738702.0  ECB_03480  cds        waaV
# 18  CTTTCCCCCAGACTCATCGA      -  2137401.0  ECB_02030  cds        yegX
# 19  GAATTCCGCCACAATGCGGC      +   482314.0  ECB_00435  cds        copA
# 20  GCGGCGTCCCCCTGCCGCTC      -   291093.0  ECB_00259  cds        ykgI
# 21  GAATAACATCGATTCTACAC      +   782643.0  ECB_00723  cds        ybhI
# 22  CCGGGGCCCAGGCCCCCCTC      +  3967938.0  ECB_03698  cds        rarD
# 23  ACACTCGGCCCCGACGACGT      -  4390294.0  ECB_04051  cds        yjfL
# 24  ATTCCAAGCTTCTCCACATA      +  3861130.0  ECB_03604  cds        yieC
# 25  ACCAAATGCCTCAGCTGCAT      -  2128076.0  ECB_02020  cds        gatA
# 26  TATAGCCTGGCATGACCGTA      +  1017699.0  ECB_00944  cds        ycbS
# 27  CCCCTGCTATCAGCAATTTC      +   826075.0  ECB_00766  cds        dinG
# 28  GTCGCGATACTTACCCGCAT      +   697884.0  ECB_00646  cds        ybfP
# 29  CCCTACCAGGCCACACCCCT      +  3793772.0  ECB_03536  cds        insI
# 30  CCCTGTACGGCTTGTTCCAC      -  2316059.0  ECB_02181  cds        yfbG
# 31  GCCCATTCCCCATCACCTCG      -  3866784.0  ECB_03607  cds        bglG
# 32  CTCCCCCCCGGTCCCGCCCT      -   154561.0  ECB_00136  cds        yadL
# 33  AAAGCCCCGCTCCCTCGCCG      +  4305975.0  ECB_03980  cds        yjdA
# 34  GAACGCCCGGATCACCCACC      +  4527702.0  ECB_04186  cds        fimD
# 35  ACGCACTCGCACCAGAAGGC      +  4041604.0  ECB_03759  cds        yihN
# 36  TACTACTCGGACCAAGTAGC      -  2006185.0  ECB_01904  cds        insD
# 37  TCTATGATGTTGCGTGGAGC      -  3729902.0  ECB_03473  cds        yibD
# 38  CGTTCAAACTCTCTTCATCG      -  2662350.0  ECB_02490  cds        aroF
# 39  CTTTCAAGTCCTGGCGGAAC      +   639220.0  ECB_00592  cds        crcA
# 40  CCACACAGTACATACCTGAC      +   294496.0  ECB_00262  cds        ykgE
# 41  TATCTCCAGCATCCCGAGCT      -    73758.0  ECB_00066  cds        araC
# 42  TCCAGCACCCTATTAGCACT      -  1552702.0  ECB_01454  cds        yddA
# 43  AGCAGAGGGCCAACGTACCT      -  1083900.0  ECB_01007  cds        wrbA
# 44  CCCTACTCCCCCTCCGGCCG      -  1989447.0  ECB_01891  cds        yeeJ
# 45  ATTTTTCCGCGTAACGCCCC      +  3119661.0  ECB_02915  cds        ygiL
# 46  GGCGAAATCGTACCCTCAAT      +   543122.0  ECB_00495  cds        ybcL
# 47  GATCCTTGCTCCCGCCCTCC      +  3675138.0  ECB_03429  cds        yiaM
# 48  CCTCAAGGCAACCAACGGCG      +  4093083.0  ECB_03808  cds        yiiT
# 49  CCGCCGCCATCTGCTATCAC      -  3205502.0  ECB_02990  cds        garR
#
#                                           description  x(0_freq)  x(1_freq)  \
# 0                               predicted transporter   0.002744   0.002859
# 1                                hypothetical protein   0.002725   0.002917
# 2                                hypothetical protein   0.002488   0.002104
# 3                    predicted nucleoside transporter   0.002035   0.001650
# 4                 predicted sugar transporter subunit   0.002151   0.001544
# 5             predicted fimbrial-like adhesin protein   0.001576   0.001876
# 6   predicted Mg(2+) transport ATPase inner membra...   0.002595   0.001876
# 7                 predicted glutathione S-transferase   0.001915   0.001814
# 8                                hypothetical protein   0.010418   0.011035
# 9                                hypothetical protein   0.001948   0.001783
# 10                              threonine dehydratase   0.002059   0.002566
# 11                                   predicted kinase   0.002271   0.001305
# 12             predicted outer membrane usher protein   0.002021   0.001845
# 13  carbohydrate-specific outer membrane porin, cr...   0.001898   0.001260
# 14                               hypothetical protein   0.002736   0.002334
# 15                               hypothetical protein   0.001790   0.002049
# 16    predicted DNA-binding transcriptional regulator   0.002101   0.002131
# 17               putative beta1,3-glucosyltransferase   0.002264   0.002588
# 18                                predicted hydrolase   0.002117   0.000753
# 19                                 copper transporter   0.002405   0.000891
# 20                               hypothetical protein   0.004270   0.003284
# 21                              predicted transporter   0.002545   0.003032
# 22      predicted chloramphenical resistance permease   0.001865   0.000476
# 23                   conserved inner membrane protein   0.002259   0.001468
# 24  carbohydrate-specific outer membrane porin, cr...   0.001720   0.001993
# 25    galactitol-specific enzyme IIA component of PTS   0.002563   0.002104
# 26             predicted outer membrane usher protein   0.001250   0.001845
# 27                         ATP-dependent DNA helicase   0.002315   0.001906
# 28                               hypothetical protein   0.002619   0.001935
# 29                                   IS30 transposase   0.003628   0.002975
# 30                               hypothetical protein   0.002266   0.001718
# 31   transcriptional antiterminator of the bgl operon   0.002524   0.002937
# 32            predicted fimbrial-like adhesin protein   0.002313   0.001650
# 33  conserved hypothetical protein with nucleoside...   0.002141   0.001429
# 34  outer membrane usher protein, type 1 fimbrial ...   0.001763   0.003106
# 35                              predicted transporter   0.002296   0.002406
# 36           IS2 insertion element transposase InsAB'   0.002943   0.002021
# 37                     predicted glycosyl transferase   0.003092   0.003088
# 38  3-deoxy-D-arabino-heptulosonate-7-phosphate sy...   0.002420   0.002358
# 39                  palmitoyl transferase for Lipid A   0.002516   0.002310
# 40                           predicted oxidoreductase   0.002374   0.003088
# 41         DNA-binding transcriptional dual regulator   0.002014   0.002310
# 42  fused predicted multidrug transporter subunits...   0.003458   0.003533
# 43                          TrpR binding protein WrbA   0.002208   0.002077
# 44                                            adhesin   0.002422   0.002498
# 45            predicted fimbrial-like adhesin protein   0.002043   0.003051
# 46                         predicted kinase inhibitor   0.001944   0.002543
# 47                              predicted transporter   0.002326   0.001468
# 48                             stress-induced protein   0.001647   0.001876
# 49                  tartronate semialdehyde reductase   0.005072   0.004928
#
#     x(2_freq)  x(3_freq)  x(4_freq)  x_corr(1)  x_corr(2)  x_corr(3)  \
# 0    0.002719   0.001560   0.001350   0.000198   0.000054  -0.001106
# 1    0.002643   0.002637   0.002310   0.000293   0.000030   0.000041
# 2    0.001949   0.002431   0.001531  -0.000283  -0.000417   0.000089
# 3    0.001602   0.002309   0.001082  -0.000376  -0.000483   0.000166
# 4    0.001784   0.002455   0.002772  -0.000574  -0.000371   0.000265
# 5    0.002604   0.001632   0.001021   0.000360   0.001098   0.000139
# 6    0.002719   0.003006   0.002724  -0.000613   0.000253   0.000567
# 7    0.001976   0.001522   0.002104  -0.000060   0.000081  -0.000389
# 8    0.012224   0.015112   0.017199   0.001173   0.002577   0.005692
# 9    0.002584   0.001444   0.002253  -0.000068   0.000767  -0.000336
# 10   0.002377   0.002455   0.001730   0.000613   0.000464   0.000585
# 11   0.002077   0.001801   0.000000  -0.000845  -0.000026  -0.000252
# 12   0.002126   0.002723   0.000000  -0.000108   0.000176   0.000780
# 13   0.001665   0.002455   0.001573  -0.000557  -0.000133   0.000679
# 14   0.001949   0.002455   0.002310  -0.000296  -0.000663  -0.000135
# 15   0.002150   0.002042   0.001768   0.000320   0.000423   0.000322
# 16   0.001063   0.001926   0.001976   0.000113  -0.000940  -0.000058
# 17   0.003091   0.004113   0.003662   0.000388   0.000881   0.001899
# 18   0.001949   0.002098   0.001614  -0.001319  -0.000148  -0.000019
# 19   0.002544   0.001597   0.001614  -0.001242   0.000589  -0.000192
# 20   0.003668   0.002888   0.002652  -0.000816  -0.000399  -0.001139
# 21   0.003361   0.002702   0.002420   0.000601   0.000963   0.000339
# 22   0.002420   0.001985   0.001692  -0.001355   0.000561   0.000102
# 23   0.001976   0.001179   0.001082  -0.000693  -0.000163  -0.000932
# 24   0.002243   0.001484   0.002195   0.000346   0.000614  -0.000125
# 25   0.002001   0.001895   0.001141  -0.000411  -0.000548  -0.000684
# 26   0.001241   0.003101   0.002420   0.000632   0.000026   0.001885
# 27   0.002243   0.002309   0.002500  -0.000330   0.000012   0.000086
# 28   0.001949   0.001484   0.001943  -0.000547  -0.000482  -0.000894
# 29   0.003268   0.003265   0.003697  -0.000542  -0.000255  -0.000257
# 30   0.002937   0.002283   0.002975  -0.000416   0.000860   0.000266
# 31   0.002052   0.003064   0.002887   0.000520  -0.000339   0.000702
# 32   0.002101   0.002744   0.002724  -0.000578  -0.000117   0.000540
# 33   0.001634   0.002098   0.001301  -0.000623  -0.000397   0.000091
# 34   0.002243   0.001076   0.001573   0.001419   0.000575  -0.000571
# 35   0.001537   0.001985   0.001573   0.000202  -0.000648  -0.000178
# 36   0.001013   0.000963   0.000000  -0.000259  -0.000813  -0.000497
# 37   0.003466   0.002659   0.004330   0.000126   0.000535  -0.000238
# 38   0.002420   0.002358   0.002135   0.000026   0.000097   0.000050
# 39   0.002001   0.000834   0.001654  -0.000132  -0.000446  -0.001615
# 40   0.001696   0.002407   0.002366   0.000783  -0.000616   0.000092
# 41   0.001923   0.001895   0.000807   0.000500   0.000243   0.000338
# 42   0.002333   0.001926   0.002627   0.000199  -0.000988  -0.001378
# 43   0.002197   0.000901   0.000000  -0.000063   0.000056  -0.001239
# 44   0.001976   0.002407   0.002748   0.000146  -0.000386   0.000040
# 45   0.002462   0.003586   0.002700   0.001086   0.000509   0.001650
# 46   0.001784   0.001985   0.002338   0.000699  -0.000025   0.000213
# 47   0.002220   0.003300   0.002282  -0.000756   0.000023   0.001133
# 48   0.001976   0.002071   0.002310   0.000292   0.000402   0.000510
# 49   0.004721   0.004642   0.004390   0.000311   0.000378   0.000565
#
#     x_corr(4)
# 0   -0.001310
# 1   -0.000262
# 2   -0.000782
# 3   -0.001113
# 4    0.000553
# 5   -0.000457
# 6    0.000317
# 7    0.000179
# 8    0.008021
# 9    0.000513
# 10  -0.000094
# 11  -0.002000
# 12  -0.001933
# 13  -0.000177
# 14  -0.000251
# 15   0.000057
# 16   0.000016
# 17   0.001447
# 18  -0.000520
# 19  -0.000018
# 20  -0.001327
# 21   0.000099
# 22  -0.000211
# 23  -0.000997
# 24   0.000610
# 25  -0.001463
# 26   0.001206
# 27   0.000290
# 28  -0.000376
# 29   0.000184
# 30   0.001021
# 31   0.000559
# 32   0.000539
# 33  -0.000679
# 34  -0.000049
# 35  -0.000564
# 36  -0.001164
# 37   0.001474
# 38  -0.000154
# 39  -0.000791
# 40   0.000054
# 41  -0.000633
# 42  -0.000650
# 43  -0.002133
# 44   0.000382
# 45   0.000784
# 46   0.000608
# 47   0.000149
# 48   0.000766
# 49   0.000570

# %%
#list of all x_corr(t) for each barcode:
xS1_corrs = dfS1_x_corr[["x_corr(1)","x_corr(2)","x_corr(3)","x_corr(4)"]].values.tolist()

def x_var(x_corrs, df_x_corr):
    x_c_var = []
    for x_c in x_corrs:
        x_var = np.var(x_c)
        x_c_var.append(x_var)
    df_x_corr["var(x_corr)"] = x_c_var

x_var(xS1_corrs, dfS1_x_corr)
dfS1_x_corr.head(50)
# Out:
#                  barcode strand        pos    gene_ID type gene_symbol  \
# 0   CCTAAGCGCTTACCCCAACC      +  2881032.0  ECB_02693  cds        yqeG
# 1   TCGGACCCAGCTTGGAATAA      +  4065973.0  ECB_03781  cds        yiiG
# 2   CCCCCCAGGCTCGTGACGCC      -  2392940.0  ECB_02257  cds        yfcO
# 3   AGTGATTGCGTATATCTGTT      +  2205123.0  ECB_02090  cds        yeiJ
# 4   GCCACAGCACCGGTCACACT      -  4437424.0  ECB_04099  cds        yjfF
# 5   CGAACCCTCCGACGCGCTTT      -  3119814.0  ECB_02915  cds        ygiL
# 6   CCCGACATCGCACGCAACGC      +  3584927.0  ECB_03356  cds        yhiD
# 7   CCCTCACCCTATTATCTGCC      -  2364812.0  ECB_02227  cds        yfcG
# 8   GCTCGTCATTAAGATTTACT      -  3825996.0  ECB_03568  cds        yidE
# 9   GCCTTCCCCCCACGTCTGCA      -  2352777.0  ECB_02216  cds        yfbR
# 10  CGTCCTGTCTCCAAACGAAA      +  3198194.0  ECB_02984  cds        tdcB
# 11  CACACTCAGAAAATCTGTTT      +  2791651.0  ECB_02620  cds        ygcE
# 12  CCACCAGTACCGATATCAGG      -   157515.0  ECB_00138  cds        htrE
# 13  CTCCCGCTCCGACACCTAAC      +  3861756.0  ECB_03604  cds        yieC
# 14  CCGGCTCTATTCTCCCACGC      +  3124250.0  ECB_02918  cds        yqiI
# 15  CAACGGAAGCAGCGGGCCGG      +  4230277.0  ECB_03910  cds        yjbI
# 16  ATGGATAACATAAGCTAACA      +  3820394.0  ECB_03564  cds        yidL
# 17  CCCTCCCGGACTCTCCGACA      +  3738702.0  ECB_03480  cds        waaV
# 18  CTTTCCCCCAGACTCATCGA      -  2137401.0  ECB_02030  cds        yegX
# 19  GAATTCCGCCACAATGCGGC      +   482314.0  ECB_00435  cds        copA
# 20  GCGGCGTCCCCCTGCCGCTC      -   291093.0  ECB_00259  cds        ykgI
# 21  GAATAACATCGATTCTACAC      +   782643.0  ECB_00723  cds        ybhI
# 22  CCGGGGCCCAGGCCCCCCTC      +  3967938.0  ECB_03698  cds        rarD
# 23  ACACTCGGCCCCGACGACGT      -  4390294.0  ECB_04051  cds        yjfL
# 24  ATTCCAAGCTTCTCCACATA      +  3861130.0  ECB_03604  cds        yieC
# 25  ACCAAATGCCTCAGCTGCAT      -  2128076.0  ECB_02020  cds        gatA
# 26  TATAGCCTGGCATGACCGTA      +  1017699.0  ECB_00944  cds        ycbS
# 27  CCCCTGCTATCAGCAATTTC      +   826075.0  ECB_00766  cds        dinG
# 28  GTCGCGATACTTACCCGCAT      +   697884.0  ECB_00646  cds        ybfP
# 29  CCCTACCAGGCCACACCCCT      +  3793772.0  ECB_03536  cds        insI
# 30  CCCTGTACGGCTTGTTCCAC      -  2316059.0  ECB_02181  cds        yfbG
# 31  GCCCATTCCCCATCACCTCG      -  3866784.0  ECB_03607  cds        bglG
# 32  CTCCCCCCCGGTCCCGCCCT      -   154561.0  ECB_00136  cds        yadL
# 33  AAAGCCCCGCTCCCTCGCCG      +  4305975.0  ECB_03980  cds        yjdA
# 34  GAACGCCCGGATCACCCACC      +  4527702.0  ECB_04186  cds        fimD
# 35  ACGCACTCGCACCAGAAGGC      +  4041604.0  ECB_03759  cds        yihN
# 36  TACTACTCGGACCAAGTAGC      -  2006185.0  ECB_01904  cds        insD
# 37  TCTATGATGTTGCGTGGAGC      -  3729902.0  ECB_03473  cds        yibD
# 38  CGTTCAAACTCTCTTCATCG      -  2662350.0  ECB_02490  cds        aroF
# 39  CTTTCAAGTCCTGGCGGAAC      +   639220.0  ECB_00592  cds        crcA
# 40  CCACACAGTACATACCTGAC      +   294496.0  ECB_00262  cds        ykgE
# 41  TATCTCCAGCATCCCGAGCT      -    73758.0  ECB_00066  cds        araC
# 42  TCCAGCACCCTATTAGCACT      -  1552702.0  ECB_01454  cds        yddA
# 43  AGCAGAGGGCCAACGTACCT      -  1083900.0  ECB_01007  cds        wrbA
# 44  CCCTACTCCCCCTCCGGCCG      -  1989447.0  ECB_01891  cds        yeeJ
# 45  ATTTTTCCGCGTAACGCCCC      +  3119661.0  ECB_02915  cds        ygiL
# 46  GGCGAAATCGTACCCTCAAT      +   543122.0  ECB_00495  cds        ybcL
# 47  GATCCTTGCTCCCGCCCTCC      +  3675138.0  ECB_03429  cds        yiaM
# 48  CCTCAAGGCAACCAACGGCG      +  4093083.0  ECB_03808  cds        yiiT
# 49  CCGCCGCCATCTGCTATCAC      -  3205502.0  ECB_02990  cds        garR
#
#                                           description  x(0_freq)  x(1_freq)  \
# 0                               predicted transporter   0.002744   0.002859
# 1                                hypothetical protein   0.002725   0.002917
# 2                                hypothetical protein   0.002488   0.002104
# 3                    predicted nucleoside transporter   0.002035   0.001650
# 4                 predicted sugar transporter subunit   0.002151   0.001544
# 5             predicted fimbrial-like adhesin protein   0.001576   0.001876
# 6   predicted Mg(2+) transport ATPase inner membra...   0.002595   0.001876
# 7                 predicted glutathione S-transferase   0.001915   0.001814
# 8                                hypothetical protein   0.010418   0.011035
# 9                                hypothetical protein   0.001948   0.001783
# 10                              threonine dehydratase   0.002059   0.002566
# 11                                   predicted kinase   0.002271   0.001305
# 12             predicted outer membrane usher protein   0.002021   0.001845
# 13  carbohydrate-specific outer membrane porin, cr...   0.001898   0.001260
# 14                               hypothetical protein   0.002736   0.002334
# 15                               hypothetical protein   0.001790   0.002049
# 16    predicted DNA-binding transcriptional regulator   0.002101   0.002131
# 17               putative beta1,3-glucosyltransferase   0.002264   0.002588
# 18                                predicted hydrolase   0.002117   0.000753
# 19                                 copper transporter   0.002405   0.000891
# 20                               hypothetical protein   0.004270   0.003284
# 21                              predicted transporter   0.002545   0.003032
# 22      predicted chloramphenical resistance permease   0.001865   0.000476
# 23                   conserved inner membrane protein   0.002259   0.001468
# 24  carbohydrate-specific outer membrane porin, cr...   0.001720   0.001993
# 25    galactitol-specific enzyme IIA component of PTS   0.002563   0.002104
# 26             predicted outer membrane usher protein   0.001250   0.001845
# 27                         ATP-dependent DNA helicase   0.002315   0.001906
# 28                               hypothetical protein   0.002619   0.001935
# 29                                   IS30 transposase   0.003628   0.002975
# 30                               hypothetical protein   0.002266   0.001718
# 31   transcriptional antiterminator of the bgl operon   0.002524   0.002937
# 32            predicted fimbrial-like adhesin protein   0.002313   0.001650
# 33  conserved hypothetical protein with nucleoside...   0.002141   0.001429
# 34  outer membrane usher protein, type 1 fimbrial ...   0.001763   0.003106
# 35                              predicted transporter   0.002296   0.002406
# 36           IS2 insertion element transposase InsAB'   0.002943   0.002021
# 37                     predicted glycosyl transferase   0.003092   0.003088
# 38  3-deoxy-D-arabino-heptulosonate-7-phosphate sy...   0.002420   0.002358
# 39                  palmitoyl transferase for Lipid A   0.002516   0.002310
# 40                           predicted oxidoreductase   0.002374   0.003088
# 41         DNA-binding transcriptional dual regulator   0.002014   0.002310
# 42  fused predicted multidrug transporter subunits...   0.003458   0.003533
# 43                          TrpR binding protein WrbA   0.002208   0.002077
# 44                                            adhesin   0.002422   0.002498
# 45            predicted fimbrial-like adhesin protein   0.002043   0.003051
# 46                         predicted kinase inhibitor   0.001944   0.002543
# 47                              predicted transporter   0.002326   0.001468
# 48                             stress-induced protein   0.001647   0.001876
# 49                  tartronate semialdehyde reductase   0.005072   0.004928
#
#     x(2_freq)  x(3_freq)  x(4_freq)  x_corr(1)  x_corr(2)  x_corr(3)  \
# 0    0.002719   0.001560   0.001350   0.000198   0.000054  -0.001106
# 1    0.002643   0.002637   0.002310   0.000293   0.000030   0.000041
# 2    0.001949   0.002431   0.001531  -0.000283  -0.000417   0.000089
# 3    0.001602   0.002309   0.001082  -0.000376  -0.000483   0.000166
# 4    0.001784   0.002455   0.002772  -0.000574  -0.000371   0.000265
# 5    0.002604   0.001632   0.001021   0.000360   0.001098   0.000139
# 6    0.002719   0.003006   0.002724  -0.000613   0.000253   0.000567
# 7    0.001976   0.001522   0.002104  -0.000060   0.000081  -0.000389
# 8    0.012224   0.015112   0.017199   0.001173   0.002577   0.005692
# 9    0.002584   0.001444   0.002253  -0.000068   0.000767  -0.000336
# 10   0.002377   0.002455   0.001730   0.000613   0.000464   0.000585
# 11   0.002077   0.001801   0.000000  -0.000845  -0.000026  -0.000252
# 12   0.002126   0.002723   0.000000  -0.000108   0.000176   0.000780
# 13   0.001665   0.002455   0.001573  -0.000557  -0.000133   0.000679
# 14   0.001949   0.002455   0.002310  -0.000296  -0.000663  -0.000135
# 15   0.002150   0.002042   0.001768   0.000320   0.000423   0.000322
# 16   0.001063   0.001926   0.001976   0.000113  -0.000940  -0.000058
# 17   0.003091   0.004113   0.003662   0.000388   0.000881   0.001899
# 18   0.001949   0.002098   0.001614  -0.001319  -0.000148  -0.000019
# 19   0.002544   0.001597   0.001614  -0.001242   0.000589  -0.000192
# 20   0.003668   0.002888   0.002652  -0.000816  -0.000399  -0.001139
# 21   0.003361   0.002702   0.002420   0.000601   0.000963   0.000339
# 22   0.002420   0.001985   0.001692  -0.001355   0.000561   0.000102
# 23   0.001976   0.001179   0.001082  -0.000693  -0.000163  -0.000932
# 24   0.002243   0.001484   0.002195   0.000346   0.000614  -0.000125
# 25   0.002001   0.001895   0.001141  -0.000411  -0.000548  -0.000684
# 26   0.001241   0.003101   0.002420   0.000632   0.000026   0.001885
# 27   0.002243   0.002309   0.002500  -0.000330   0.000012   0.000086
# 28   0.001949   0.001484   0.001943  -0.000547  -0.000482  -0.000894
# 29   0.003268   0.003265   0.003697  -0.000542  -0.000255  -0.000257
# 30   0.002937   0.002283   0.002975  -0.000416   0.000860   0.000266
# 31   0.002052   0.003064   0.002887   0.000520  -0.000339   0.000702
# 32   0.002101   0.002744   0.002724  -0.000578  -0.000117   0.000540
# 33   0.001634   0.002098   0.001301  -0.000623  -0.000397   0.000091
# 34   0.002243   0.001076   0.001573   0.001419   0.000575  -0.000571
# 35   0.001537   0.001985   0.001573   0.000202  -0.000648  -0.000178
# 36   0.001013   0.000963   0.000000  -0.000259  -0.000813  -0.000497
# 37   0.003466   0.002659   0.004330   0.000126   0.000535  -0.000238
# 38   0.002420   0.002358   0.002135   0.000026   0.000097   0.000050
# 39   0.002001   0.000834   0.001654  -0.000132  -0.000446  -0.001615
# 40   0.001696   0.002407   0.002366   0.000783  -0.000616   0.000092
# 41   0.001923   0.001895   0.000807   0.000500   0.000243   0.000338
# 42   0.002333   0.001926   0.002627   0.000199  -0.000988  -0.001378
# 43   0.002197   0.000901   0.000000  -0.000063   0.000056  -0.001239
# 44   0.001976   0.002407   0.002748   0.000146  -0.000386   0.000040
# 45   0.002462   0.003586   0.002700   0.001086   0.000509   0.001650
# 46   0.001784   0.001985   0.002338   0.000699  -0.000025   0.000213
# 47   0.002220   0.003300   0.002282  -0.000756   0.000023   0.001133
# 48   0.001976   0.002071   0.002310   0.000292   0.000402   0.000510
# 49   0.004721   0.004642   0.004390   0.000311   0.000378   0.000565
#
#     x_corr(4)   var(x_corr)
# 0   -0.001310  4.524255e-07
# 1   -0.000262  3.861233e-08
# 2   -0.000782  9.698366e-08
# 3   -0.001113  2.064971e-07
# 4    0.000553  2.098191e-07
# 5   -0.000457  3.096820e-07
# 6    0.000317  1.982289e-07
# 7    0.000179  4.624818e-08
# 8    0.008021  7.128679e-06
# 9    0.000513  1.943125e-07
# 10  -0.000094  8.185595e-08
# 11  -0.002000  5.851495e-07
# 12  -0.001933  1.022858e-06
# 13  -0.000177  2.027974e-07
# 14  -0.000251  3.896994e-08
# 15   0.000057  1.842775e-08
# 16   0.000016  1.775660e-07
# 17   0.001447  3.255739e-07
# 18  -0.000520  2.567101e-07
# 19  -0.000018  4.349145e-07
# 20  -0.001327  1.240133e-07
# 21   0.000099  1.028187e-07
# 22  -0.000211  5.003040e-07
# 23  -0.000997  1.076041e-07
# 24   0.000610  9.060833e-08
# 25  -0.001463  1.664901e-07
# 26   0.001206  4.736529e-07
# 27   0.000290  4.993806e-08
# 28  -0.000376  3.762422e-08
# 29   0.000184  6.726648e-08
# 30   0.001021  3.193372e-07
# 31   0.000559  1.677359e-07
# 32   0.000539  2.232830e-07
# 33  -0.000679  9.199123e-08
# 34  -0.000049  5.497547e-07
# 35  -0.000564  1.144051e-07
# 36  -0.001164  1.156227e-07
# 37   0.001474  4.082603e-07
# 38  -0.000154  9.091238e-09
# 39  -0.000791  3.061161e-07
# 40   0.000054  2.447444e-07
# 41  -0.000633  1.934016e-07
# 42  -0.000650  3.382329e-07
# 43  -0.002133  8.095639e-07
# 44   0.000382  7.737822e-08
# 45   0.000784  1.792390e-07
# 46   0.000608  8.628433e-08
# 47   0.000149  4.504615e-07
# 48   0.000766  3.093022e-08
# 49   0.000570  1.300082e-08

# %%
#create df with variances and corresponding geneIDs
def list_genes(df_x_corr):
    updated_genes = []
    for gene in df_x_corr["gene_ID"].tolist():
        if gene not in updated_genes:
            updated_genes.append(gene)
    return updated_genes

#getting average variance of barcodes in each gene:
def avg_var(df_x_corr):
    avg_vars = []
    std_vars = []
    for gene in list_genes(df_x_corr):
        df_gene = df_x_corr.loc[df_x_corr["gene_ID"] == gene]
        x_vars = df_gene["var(x_corr)"].mean()
        avg_vars.append(x_vars)
        x_std = np.sqrt(x_vars)
        std_vars.append(x_std)
    return [avg_vars, std_vars]

bcS1_data = {"gene_ID": list_genes(dfS1_x_corr), "avg_var(x_corr)": avg_var(dfS1_x_corr)[0], "std(x_corr)": avg_var(dfS1_x_corr)[1]}
dfS1_bc = pd.DataFrame(bcS1_data)
dfS1_bc = dfS1_bc.sort_values(by = 'avg_var(x_corr)', ascending=[False])
dfS1_bc = dfS1_bc.reset_index() 
dfS1_bc.head(50)
# Out:
#     index    gene_ID  avg_var(x_corr)  std(x_corr)
# 0     642  ECB_02593     2.878033e-06     0.001696
# 1    2455  ECB_03262     2.357972e-06     0.001536
# 2    2420  ECB_00584     1.920707e-06     0.001386
# 3     842  ECB_04077     1.825601e-06     0.001351
# 4    1387  ECB_02782     1.754994e-06     0.001325
# 5     271  ECB_02794     1.722669e-06     0.001313
# 6     750  ECB_02844     1.648766e-06     0.001284
# 7    2219  ECB_00418     1.645154e-06     0.001283
# 8     385  ECB_02840     1.432677e-06     0.001197
# 9    2495  ECB_03866     1.406146e-06     0.001186
# 10   2357  ECB_00972     1.047768e-06     0.001024
# 11   2377  ECB_04253     1.040556e-06     0.001020
# 12   2039  ECB_02558     1.036872e-06     0.001018
# 13   2265  ECB_01800     1.021609e-06     0.001011
# 14   2615  ECB_01154     9.340219e-07     0.000966
# 15   2527  ECB_00969     9.184504e-07     0.000958
# 16   1106  ECB_02700     9.150752e-07     0.000957
# 17   1214  ECB_00581     8.409442e-07     0.000917
# 18   2435  ECB_02233     8.273031e-07     0.000910
# 19   2438  ECB_02958     8.267233e-07     0.000909
# 20    206  ECB_02847     8.223269e-07     0.000907
# 21   2553  ECB_03297     7.927108e-07     0.000890
# 22   2022  ECB_03131     7.914039e-07     0.000890
# 23    600  ECB_00717     7.909482e-07     0.000889
# 24   1292  ECB_02839     7.856100e-07     0.000886
# 25      8  ECB_03568     7.766519e-07     0.000881
# 26   2284  ECB_01248     7.667519e-07     0.000876
# 27   1674  ECB_00039     7.664351e-07     0.000875
# 28   1788  ECB_03686     7.466571e-07     0.000864
# 29   2456  ECB_02027     7.462621e-07     0.000864
# 30   1146  ECB_02690     7.326474e-07     0.000856
# 31   2071  ECB_01986     7.085424e-07     0.000842
# 32   1667  ECB_02611     7.075863e-07     0.000841
# 33   2669  ECB_00227     7.019987e-07     0.000838
# 34   2385  ECB_02387     6.988730e-07     0.000836
# 35    810  ECB_03777     6.920675e-07     0.000832
# 36   2193  ECB_02218     6.861707e-07     0.000828
# 37   2395  ECB_03316     6.795253e-07     0.000824
# 38   2457  ECB_01140     6.614415e-07     0.000813
# 39   1391  ECB_02465     6.569085e-07     0.000810
# 40     64  ECB_02888     6.535763e-07     0.000808
# 41     83  ECB_02235     6.430262e-07     0.000802
# 42   1621  ECB_01320     6.428675e-07     0.000802
# 43   2002  ECB_02731     6.420328e-07     0.000801
# 44    240  ECB_02505     6.355047e-07     0.000797
# 45   1463  ECB_02901     6.342219e-07     0.000796
# 46   2590  ECB_02415     6.324430e-07     0.000795
# 47   2446  ECB_02136     6.147649e-07     0.000784
# 48   1597  ECB_02101     6.126353e-07     0.000783
# 49   2334  ECB_03984     6.101486e-07     0.000781

# %%
dfS1_bc.to_csv('FS1.csv')

# %%
#first 3 genes with highest variance:
def plot_x(df_gene, gene_ID):
    for i in range(len(df_gene)):
        barcode = df_gene.iloc[i,0]
        x_array = df_gene.iloc[i,8:12].tolist()
        days = [1, 2, 3, 4]
        plt.plot(days, x_array)#, label = barcode)
        plt.xticks(np.arange(1,len(days)+1,1))
        plt.xlabel("Days")
        plt.ylabel("x(t)")
        plt.ylim([-0.02,0.02])
        #plt.legend()
        plt.title(gene_ID)
    plt.show()
    
def plot_x_corr(df_gene, gene_ID):
    for i in range(len(df_gene)):
        barcode = df_gene.iloc[i,0]
        x_array = df_gene.iloc[i,12:16].tolist()
        days = [1, 2, 3, 4]
        plt.plot(days, x_array)#, label = barcode)
        plt.xticks(np.arange(1,len(days)+1,1))
        plt.xlabel("Days")
        plt.ylabel("x_corr(t)")
        plt.ylim([-0.02,0.02])
        #plt.legend()
        plt.title(gene_ID)
    plt.show()

def plot_gene_x(gene_ID, df_x_corr):
    #gene_ID = df_bc.iloc[i, 1] #1 is index of gene_ID
    df_gene = df_x_corr.loc[df_x_corr["gene_ID"] == gene_ID]
    plot_x(df_gene, gene_ID)
    
def plot_gene_x_corr(gene_ID, df_x_corr):
    #gene_ID = df_bc.iloc[i, 1] #1 is index of gene_ID
    df_gene = df_x_corr.loc[df_x_corr["gene_ID"] == gene_ID]
    plot_x_corr(df_gene, gene_ID)
    
def plot_first(df_bc, df_x_corr, n): #number of first nth genes to plot for df_bc
    gene_order = df_bc["gene_ID"].tolist()
    for gene in gene_order[0:n]:
        plot_gene_x(gene, df_x_corr)
        plot_gene_x_corr(gene, df_x_corr)
        
def plot_last(df_bc, df_x_corr, n): #number of first nth genes to plot for df_bc
    gene_order = df_bc["gene_ID"].tolist()
    for gene in gene_order[-n:]:
        plot_gene_x(gene, df_x_corr)
        plot_gene_x_corr(gene, df_x_corr)

# %%
all_dfs["ECB_02593"]
# Out:
#          index               barcode  0_1  0_2    1    2    3    4 strand  \
# 4638      6529  AGGCTCCACCTAAACGACTT  535  573  404  380  620  486      -
# 11521    16078  CCCTCTACACGCACTGCCCC   25   16   35   13   17   24      -
# 40229    56207  GACGGGTGTCAGCTAAGTAC   13   26    5    0   21    8      +
# 78166   109249  GATGAGAACCACAGGTTCCC   25   47   25   26    8    0      -
# 112087  156759  TTGCCGTTTAGAATAGGCTT    6   13    0    0    0    0      +
# 117298  164002  ACTCACGCAACGCCTTTCGG   41   45    4    0    0    0      +
# 126010  176223  GTAGAATCTGTGGAGTTGTG   17   20    0   14    3    0      -
# 133369  186478  CATGTTTTCAAATAATACTC   24   30    8   14    4    0      +
#
#               pos    gene_ID type gene_symbol  \
# 4638    2764066.0  ECB_02593  cds         pcm
# 11521   2764331.0  ECB_02593  cds         pcm
# 40229   2764193.0  ECB_02593  cds         pcm
# 78166   2764066.0  ECB_02593  cds         pcm
# 112087  2764066.0  ECB_02593  cds         pcm
# 117298  2764238.0  ECB_02593  cds         pcm
# 126010  2764201.0  ECB_02593  cds         pcm
# 133369  2764191.0  ECB_02593  cds         pcm
#
#                                        description
# 4638    protein-L-isoaspartate O-methyltransferase
# 11521   protein-L-isoaspartate O-methyltransferase
# 40229   protein-L-isoaspartate O-methyltransferase
# 78166   protein-L-isoaspartate O-methyltransferase
# 112087  protein-L-isoaspartate O-methyltransferase
# 117298  protein-L-isoaspartate O-methyltransferase
# 126010  protein-L-isoaspartate O-methyltransferase
# 133369  protein-L-isoaspartate O-methyltransferase

# %%
plot_first(dfS1_bc, dfS1_x_corr, 5)

# %%
plot_last(dfS1_bc, dfS1_x_corr, 3)
